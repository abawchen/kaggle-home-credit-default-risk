# %%
import datetime
import gc
import os
import time
import numpy as np
import pandas as pd
import json

from colorama import Fore, Style

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from bayes_opt import BayesianOptimization

from utils import ModelWrapper
from utils.preprocess import load_all
from utils.utils import (
    highlight_print, timer, submit, calculate_feature_importance, load_feats,
)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def exp_feats(df):
    df['BAO_CREDIT__ANNUNITY'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_ANNUITY']
    df['BAO_CREDIT__INC'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_INCOME_TOTAL']
    df['BAO_CREDIT__CREDIT'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_CREDIT']
    df['BAO_CREDIT__GOODS'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_GOODS_PRICE']
    
    df['PAO_CREDIT__ANNUNITY'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_ANNUITY']
    df['PAO_CREDIT__INC'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_INCOME_TOTAL']
    df['PAO_CREDIT__CREDIT'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_CREDIT']
    df['PAO_CREDIT__GOODS'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_GOODS_PRICE']
    
    df['PAO_ANNUNITY'] = df['PREV_AMT_ANNUITY_MEAN'] / df['AMT_ANNUITY']
    df['PAO_ANNUNITY__INC'] = df['PREV_AMT_ANNUITY_MEAN'] / df['AMT_INCOME_TOTAL']
    df['PAO_ANNUNITY__CREDIT'] = df['PREV_AMT_ANNUITY_MEAN'] / df['AMT_CREDIT']
    
    df["IBO_PAYMENT__ACREDIT"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['ACTIVE_AMT_CREDIT_SUM_SUM']
    df["IBO_PAYMENT__CCREDIT"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['CLOSED_AMT_CREDIT_SUM_SUM']
    df["IAO_PAYMENT__ANNUITY"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['AMT_ANNUITY']
    df["IAO_PAYMENT__INC"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['AMT_INCOME_TOTAL']
    
    # New try, failed
#     df['IAX_DPD__ANNUITY'] = df['INSTAL_DPD_MEAN'] * df['AMT_ANNUITY']
#     df['IAX_DPD__INC'] = df['INSTAL_DPD_MEAN'] * df['AMT_INCOME_TOTAL']
#     df['AIO_ANNUITY__DPD'] = df['AMT_ANNUITY'] / df['INSTAL_DPD_MEAN']
#     df['AIO_INC__DPD'] = df['AMT_INCOME_TOTAL'] / df['INSTAL_DPD_MEAN']
#     df['IBX_DPD_CREDIT_MAX_OVERDUE'] = df['INSTAL_DPD_MEAN'] * df['BURO_AMT_CREDIT_MAX_OVERDUE_MEAN']
#     df['IBM_DPD_CREDIT_MAX_OVERDUE'] = df['INSTAL_DPD_MEAN'] - df['BURO_AMT_CREDIT_MAX_OVERDUE_MEAN']
    # df['BAO_CREDIT_MAX_OVERDUE__ANNUITY'] = df["ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN"] / df['AMT_ANNUITY']
    # df['BAO_CREDIT_MAX_OVERDUE__INC'] = df["ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN"] / df['AMT_INCOME_TOTAL']
    # df["IAO_PAYMENT__CREDIT"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['AMT_CREDIT']
    # df["IAO_PAYMENT__GOODS"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['AMT_GOODS_PRICE']
    # df['CAO_CREDIT__ANNUITY'] = df["CLOSED_AMT_CREDIT_SUM_MEAN"] / df['AMT_ANNUITY']
    # df['CAO_CREDIT__INC'] = df["CLOSED_AMT_CREDIT_SUM_MEAN"] / df['AMT_INCOME_TOTAL']
    # df['CAO_CREDIT__CREDIT'] = df["CLOSED_AMT_CREDIT_SUM_MEAN"] / df['AMT_CREDIT']
    # df['CAO_CREDIT__GOODS'] = df["CLOSED_AMT_CREDIT_SUM_MEAN"] / df['AMT_GOODS_PRICE']
    
    return df

# %%
with timer('Load features'):
    df = load_all('../data/preprocess')
    print("df shape:", df.shape)
# Out:
# df shape: (356251, 877)
# [Done] Load features in 1:49 (2018-08-21 21:54:16.385110)

# %%
df_exp = df.copy()
df_exp = exp_feats(df)
print("df_exp shape:", df_exp.shape)
# Out:
# df_exp shape: (356251, 906)

# %%
df_full = df_exp.copy()

# %%
df_full['/:IAO_PAYMENT__ANNUITY:PREV_APPROVED_CNT_PAYMENT_MEAN'] = df_full['IAO_PAYMENT__ANNUITY']/df_full['PREV_APPROVED_CNT_PAYMENT_MEAN']
df_full['/:PREV_APPROVED_CNT_PAYMENT_MEAN:INSTAL_DAYS_ENTRY_PAYMENT_MAX'] = df_full['PREV_APPROVED_CNT_PAYMENT_MEAN']/df_full['INSTAL_DAYS_ENTRY_PAYMENT_MAX']

# %%
train_df = df_full[df_full['TARGET'].notnull()]
test_df = df_full[df_full['TARGET'].isnull()]
print("train_df shape:", train_df.shape)
print("test_df shape:", test_df.shape)
# Out:
# train_df shape: (307507, 908)
# test_df shape: (48744, 908)

# %%
# base = '106_m_lgbm_03'
base = '91_mb_lgbm5_04'
model_folder = os.path.join('..', 'expmodel', base)
feats = load_feats(model_folder, 'feats.json')
# drop_feats = []
if feats is not None:
    print('Load feats from {}'.format(model_folder))
    drop_feats = list(set(df_full.columns) - set(feats))
else:
    skip_feats = ['TARGET', 'SK_ID_CURR', 'SK_ID_BUREAU', 'SK_ID_PREV', 'index'] + drop_feats
    feats = [f for f in df_full.columns if f not in skip_feats]
trying_feats = [
    'IAX_DPD__ANNUITY',
#     'IAX_DPD__INC',
#     'AIO_ANNUITY__DPD',
#     'AIO_INC__DPD',
#     'IBX_DPD_CREDIT_MAX_OVERDUE',
    'IBM_DPD_CREDIT_MAX_OVERDUE',
    # 'BAO_CREDIT_MAX_OVERDUE__ANNUITY', 'BAO_CREDIT_MAX_OVERDUE__INC'
]
feats += trying_feats
print('feats num: {}, drop_feats: {}'.format(len(feats), len(drop_feats)))
# Out:
# Load feats from ../expmodel/91_mb_lgbm5_04
# feats num: 653, drop_feats: 257

# %%
X_train = train_df[feats]
X_test = test_df[feats]
y_train = train_df['TARGET']
print("X_train df shape:", X_train.shape)
# Out:
# X_train df shape: (307507, 653)

# %%
def feature_importance(n_fold, clf, feats):
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = n_fold+1
    return fold_importance_df

# %%
import importlib
importlib.reload(ModelWrapper)

r = 9
nums_fold = 3
prefix = '106_{}_lgbm{}_{}'.format('m', nums_fold, str(r).zfill(2))
# prefix = '91_mb_lgbm5_04'
model_folder = os.path.join('..', 'expmodel', prefix)

random_state = 1001
params = {}
# params = {
#     'colsample_bytree': 0.7642713022545912,
#     'learning_rate': 0.010414356455472869,
#     'num_leaves': 33.01866087439472,
#     'subsample': 0.9695097184671164,
#     'max_depth': 10.865363258675153,
#     'reg_alpha': 0.046479938861221405,
#     'reg_lambda': 0.06363252146721826,
#     'min_split_gain': 0.021696909262842037,
#     'min_child_weight': 40.0454581921338
# }
params = {
  "colsample_bytree": 0.7613328838991742,
  "learning_rate": 0.010362683637634058,
  "num_leaves": 35,
  "subsample": 0.7911882154304066,
  "max_depth": 10,
  "reg_alpha": 0.04764317714601435,
  "reg_lambda": 0.06573583739775202,
  "min_split_gain": 0.027665712181798835,
  "min_child_weight": 37.78459404044409,
  "n_estimators": 10000,
}
params['n_estimators'] = 10000
params['max_depth'] = int(params['max_depth'])
params['num_leaves'] = int(params['num_leaves'])

fit_params = {
    'eval_metric': 'auc',
    'early_stopping_rounds': 200,
    'verbose': 1000,
}

folds = KFold(n_splits=nums_fold, shuffle=True, random_state=random_state)
model = ModelWrapper.ModelWrapper(
    CLF=LGBMClassifier,
    name="LightGBM",
    model_folder=model_folder,
    feats=feats,
    drop_feats=drop_feats,
    params=params,
    fit_params=fit_params
)

# %%
n_fold = 0
feature_importance_df = pd.DataFrame()
for clf, fold_auc in model.folds_train(folds, X_train, y_train, X_test):
    highlight_print(Fore.LIGHTBLUE_EX, '- %.6f (%s)' % (fold_auc, datetime.datetime.now()))
    fold_importance_df = feature_importance(n_fold, clf, feats)
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    n_fold += 1
    del clf, fold_importance_df
    gc.collect()

score = roc_auc_score(y_train, model.oof_preds_df)
highlight_print(Fore.RED, '## %s: %.6f' % (model.name, score))
model.scores.append(score)
model.serialize_scores()
# Out:
# feats num: 653
# model folder: ../expmodel/106_m_lgbm3_09
# ../expmodel/106_m_lgbm3_09/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.78762
# [2000]	valid_0's auc: 0.7904
# Early stopping, best iteration is:
# [2583]	valid_0's auc: 0.7908
# - 0.790800 (2018-08-26 09:26:09.663660)
# ../expmodel/106_m_lgbm3_09/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.787382
# [2000]	valid_0's auc: 0.790703
# Early stopping, best iteration is:
# [2739]	valid_0's auc: 0.791064
# - 0.791064 (2018-08-26 09:44:52.153104)
# ../expmodel/106_m_lgbm3_09/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.789557
# [2000]	valid_0's auc: 0.792432
# [3000]	valid_0's auc: 0.792775
# Early stopping, best iteration is:
# [2863]	valid_0's auc: 0.792814
# - 0.792814 (2018-08-26 10:07:37.551145)
# ## LightGBM: 0.791522

# %%
feature_importance_df = calculate_feature_importance(feature_importance_df, model_folder)

# %%
feature_importance_df

# %%
b_round = 0
b_feature_importance_df = pd.DataFrame()

n_iter = 5
n_splits = 3
prefix = '106_{}_lgbm{}_{}_{}'.format('b', nums_fold, n_iter, str(r).zfill(2))
model_folder = os.path.join('..', 'expmodel', prefix)

def lgbm_evaluate(**params):
    warnings.simplefilter('ignore')
    global b_feature_importance_df
    global b_round

    params['n_estimators'] = 10000
    params['num_leaves'] = int(params['num_leaves'])
    params['max_depth'] = int(params['max_depth'])
    # params['max_bin'] = 1023
    # params['boosting'] = 'dart'
    # params['device_type'] = 'gpu'
    # params['gpu_use_dp'] = True
    clf = LGBMClassifier(**params)
    model_subfolder = os.path.join(model_folder, str(b_round))
    try:
        os.makedirs(model_folder)
    except:
        pass
    folds = KFold(n_splits=n_splits, shuffle=True, random_state=1001)
    b_model = ModelWrapper.ModelWrapper(
        CLF=LGBMClassifier,
        name="LightGBM",
        model_folder=model_subfolder,
        feats=feats,
        drop_feats=drop_feats,
        params=params,
        fit_params=fit_params
    )
    n_fold = 0
    for clf, fold_auc in b_model.folds_train(folds, X_train, y_train, X_test):
        fold_importance_df = feature_importance(n_fold, clf, feats)
        b_feature_importance_df = pd.concat([b_feature_importance_df, fold_importance_df], axis=0)
        n_fold += 1
        del clf, fold_importance_df
        gc.collect()

    score = roc_auc_score(y_train, b_model.oof_preds_df)
    b_model.scores.append(score)
    b_model.serialize_scores()
    b_round += 1
    return score

with timer("BayesianOptimization:"):
    b_params = {
        'colsample_bytree': (0.75, 1),
        'learning_rate': (.01, .02),
        'num_leaves': (33, 36),
        'subsample': (0.75, 1),
        'max_depth': (6, 11),
        'reg_alpha': (.0275, .05),
        'reg_lambda': (.06, .08),
        'min_split_gain': (.0075, .03),
        'min_child_weight': (37.75, 40.25)
    }
    bo = BayesianOptimization(lgbm_evaluate, b_params)
    bo.maximize(init_points=5, n_iter=4)
# Out:
# Initialization
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   learning_rate |   max_depth |   min_child_weight |   min_split_gain |   num_leaves |   reg_alpha |   reg_lambda |   subsample |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/0
# ../expmodel/106_b_lgbm3_5_09/0/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788894
# [2000]	valid_0's auc: 0.789764
# Early stopping, best iteration is:
# [1839]	valid_0's auc: 0.789874
# ../expmodel/106_b_lgbm3_5_09/0/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788669
# [2000]	valid_0's auc: 0.790069
# Early stopping, best iteration is:
# [2395]	valid_0's auc: 0.790407
# ../expmodel/106_b_lgbm3_5_09/0/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.790549
# [2000]	valid_0's auc: 0.79195
# Early stopping, best iteration is:
# [2158]	valid_0's auc: 0.792043
#     1 | 50m56s |    0.79076 |             0.9722 |          0.0156 |      9.4190 |            38.9285 |           0.0295 |      33.9632 |      0.0455 |       0.0644 |      0.9310 |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/1
# ../expmodel/106_b_lgbm3_5_09/1/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.787996
# [2000]	valid_0's auc: 0.790068
# Early stopping, best iteration is:
# [1878]	valid_0's auc: 0.790101
# ../expmodel/106_b_lgbm3_5_09/1/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788748
# [2000]	valid_0's auc: 0.790761
# Early stopping, best iteration is:
# [1937]	valid_0's auc: 0.790798
# ../expmodel/106_b_lgbm3_5_09/1/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.790281
# [2000]	valid_0's auc: 0.792425
# Early stopping, best iteration is:
# [2126]	valid_0's auc: 0.792572
#     2 | 34m31s |    0.79111 |             0.8337 |          0.0171 |      6.3793 |            38.4689 |           0.0242 |      35.8600 |      0.0347 |       0.0624 |      0.9825 |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/2
# ../expmodel/106_b_lgbm3_5_09/2/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.786357
# [2000]	valid_0's auc: 0.789392
# Early stopping, best iteration is:
# [2694]	valid_0's auc: 0.789816
# ../expmodel/106_b_lgbm3_5_09/2/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.787475
# [2000]	valid_0's auc: 0.789999
# Early stopping, best iteration is:
# [2602]	valid_0's auc: 0.790285
# ../expmodel/106_b_lgbm3_5_09/2/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788979
# [2000]	valid_0's auc: 0.791852
# Early stopping, best iteration is:
# [2570]	valid_0's auc: 0.792128
#     3 | 46m31s |    0.79070 |             0.9250 |          0.0140 |      6.4911 |            39.5552 |           0.0142 |      33.4225 |      0.0452 |       0.0724 |      0.8954 |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/3
# ../expmodel/106_b_lgbm3_5_09/3/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.786823
# [2000]	valid_0's auc: 0.789465
# Early stopping, best iteration is:
# [2309]	valid_0's auc: 0.789621
# ../expmodel/106_b_lgbm3_5_09/3/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.787518
# [2000]	valid_0's auc: 0.789924
# Early stopping, best iteration is:
# [2474]	valid_0's auc: 0.790163
# ../expmodel/106_b_lgbm3_5_09/3/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.789051
# [2000]	valid_0's auc: 0.791591
# Early stopping, best iteration is:
# [2420]	valid_0's auc: 0.791931
#     4 | 43m44s |    0.79054 |             0.9368 |          0.0143 |      6.9073 |            39.1086 |           0.0204 |      35.3648 |      0.0323 |       0.0634 |      0.9512 |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/4
# ../expmodel/106_b_lgbm3_5_09/4/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.787677
# [2000]	valid_0's auc: 0.789655
# Early stopping, best iteration is:
# [1911]	valid_0's auc: 0.789678
# ../expmodel/106_b_lgbm3_5_09/4/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.78842
# [2000]	valid_0's auc: 0.79063
# Early stopping, best iteration is:
# [2677]	valid_0's auc: 0.790883
# ../expmodel/106_b_lgbm3_5_09/4/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.789882
# [2000]	valid_0's auc: 0.792162
# Early stopping, best iteration is:
# [2423]	valid_0's auc: 0.792504
#     5 | 46m39s |    0.79100 |             0.8791 |          0.0139 |      7.1355 |            38.7576 |           0.0083 |      34.3049 |      0.0468 |       0.0715 |      0.9941 |
# Bayesian Optimization
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   learning_rate |   max_depth |   min_child_weight |   min_split_gain |   num_leaves |   reg_alpha |   reg_lambda |   subsample |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/5
# ../expmodel/106_b_lgbm3_5_09/5/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788206
# Early stopping, best iteration is:
# [1731]	valid_0's auc: 0.789898
# ../expmodel/106_b_lgbm3_5_09/5/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788736
# [2000]	valid_0's auc: 0.790124
# Early stopping, best iteration is:
# [1981]	valid_0's auc: 0.790155
# ../expmodel/106_b_lgbm3_5_09/5/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.789928
# [2000]	valid_0's auc: 0.791364
# Early stopping, best iteration is:
# [1853]	valid_0's auc: 0.791445
#     6 | 37m55s |    0.79047 |             0.9877 |          0.0181 |      6.2066 |            37.8035 |           0.0299 |      33.0654 |      0.0362 |       0.0646 |      0.8059 |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/6
# ../expmodel/106_b_lgbm3_5_09/6/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788472
# [2000]	valid_0's auc: 0.790349
# Early stopping, best iteration is:
# [2258]	valid_0's auc: 0.790461
# ../expmodel/106_b_lgbm3_5_09/6/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.788883
# [2000]	valid_0's auc: 0.790742
# Early stopping, best iteration is:
# [2372]	valid_0's auc: 0.79116
# ../expmodel/106_b_lgbm3_5_09/6/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.790375
# [2000]	valid_0's auc: 0.792493
# Early stopping, best iteration is:
# [2264]	valid_0's auc: 0.792656
#     7 | 45m03s |    0.79138 |             0.7515 |          0.0132 |     10.7355 |            37.9667 |           0.0160 |      33.2443 |      0.0390 |       0.0647 |      0.7526 |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/7
# ../expmodel/106_b_lgbm3_5_09/7/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.789402
# Early stopping, best iteration is:
# [1710]	valid_0's auc: 0.790883
# ../expmodel/106_b_lgbm3_5_09/7/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.789266
# [2000]	valid_0's auc: 0.790941
# Early stopping, best iteration is:
# [2140]	valid_0's auc: 0.791007
# ../expmodel/106_b_lgbm3_5_09/7/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.791018
# [2000]	valid_0's auc: 0.792643
# Early stopping, best iteration is:
# [2112]	valid_0's auc: 0.792696
#     8 | 40m46s |    0.79150 |             0.7763 |          0.0146 |     10.9094 |            39.9354 |           0.0203 |      33.0278 |      0.0387 |       0.0673 |      0.9857 |
# feats num: 653
# model folder: ../expmodel/106_b_lgbm3_5_09/8
# ../expmodel/106_b_lgbm3_5_09/8/LightGBM_0.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.790029
# Early stopping, best iteration is:
# [1042]	valid_0's auc: 0.790167
# ../expmodel/106_b_lgbm3_5_09/8/LightGBM_1.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.789822
# Early stopping, best iteration is:
# [1270]	valid_0's auc: 0.79057
# ../expmodel/106_b_lgbm3_5_09/8/LightGBM_2.pickle not exists, going to train.
# Training until validation scores don't improve for 200 rounds.
# [1000]	valid_0's auc: 0.791925
# Early stopping, best iteration is:
# [1569]	valid_0's auc: 0.792616
#     9 | 29m36s |    0.79109 |             0.7591 |          0.0199 |     10.7438 |            37.8340 |           0.0182 |      35.4765 |      0.0498 |       0.0695 |      0.9993 |
# [Done] BayesianOptimization: at 2018-08-26 16:24:58.561648

# %%
cols = b_feature_importance_df[["feature", "importance"]]\
    .groupby("feature")\
    .mean()\
    .sort_values(by="importance", ascending=False)

with open(os.path.join(model_folder, 'b_feats_importance.json'), 'w') as f:
    d = dict((i, r) for i, r in cols['importance'].iteritems())
    json.dump(d, f, indent=2)

with open(os.path.join(model_folder, 'params.json'), 'w') as f:
    json.dump(bo.res['max'], f, indent=2)

bo.res['max'], model_folder
# Out:
# ({'max_val': 0.7915209761073426,
#   'max_params': {'colsample_bytree': 0.7694740743316772,
#    'learning_rate': 0.01310154058346192,
#    'num_leaves': 35.80256673316539,
#    'subsample': 0.7555353463722276,
#    'max_depth': 10.66603361173349,
#    'reg_alpha': 0.029991443322690534,
#    'reg_lambda': 0.07708551802836272,
#    'min_split_gain': 0.011336053625914954,
#    'min_child_weight': 40.24016817690307}},
#  '../expmodel/106_b_lgbm5_5_08')

# %%
"""
## LightGBM: 0.793113, 0.796
- 0.795078 (2018-08-24 21:50:48.978086)
- 0.791264 (2018-08-24 21:50:51.429607)
- 0.791956 (2018-08-24 21:50:53.210522)
- 0.791788 (2018-08-24 21:50:55.030508)
- 0.795513 (2018-08-24 21:50:56.886642)
"""

# %%
submit(prefix, test_df, model.test_preds_df)
# Out:
# ../data/submission/91_mb_lgbm5_04.csv

# %%
for i, r in feature_importance_df['importance'].iteritems():
#     if r == 0:
#        print("'{}',".format(i))
        print("'{}':'{}',".format(i, r))
# Out:
# 'AA_SOURCES_MEAN':'1101.3333333333333',
# 'DAYS_BIRTH':'1038.0',
# '/:IAO_PAYMENT__ANNUITY:PREV_APPROVED_CNT_PAYMENT_MEAN':'960.0',
# 'AAO_ANNUITY__CREDIT':'859.0',
# 'ACTIVE_DEBT_CREDIT_RATIO':'852.3333333333334',
# 'AAO_CREDIT__ANNUITY':'845.0',
# 'EXT_SOURCE_3':'816.0',
# 'EXT_SOURCE_2':'784.0',
# 'AAO_CREDIT__GOODS':'755.3333333333334',
# 'DAYS_ID_PUBLISH':'737.6666666666666',
# '/:PREV_APPROVED_CNT_PAYMENT_MEAN:INSTAL_DAYS_ENTRY_PAYMENT_MAX':'697.0',
# 'EXT_SOURCE_1':'651.6666666666666',
# 'ACTIVE_DAYS_CREDIT_MAX':'634.6666666666666',
# 'AAAX_CREDIT_ANNUITY__SOURCE_3':'634.0',
# 'AMT_ANNUITY':'624.6666666666666',
# 'AAAX_SOURCES_MEAN__EMPLOYED':'607.0',
# 'REGION_POPULATION_RELATIVE':'600.3333333333334',
# 'DAYS_REGISTRATION':'575.6666666666666',
# 'AAO_ANNUITY__INC':'558.3333333333334',
# 'ACTIVE_DAYS_CREDIT_ENDDATE_MIN':'550.6666666666666',
# 'AAAX_SOURCES_MEAN__BIRTH':'545.0',
# 'PREV_APPROVED_CNT_PAYMENT_MEAN':'536.0',
# 'IAX_DPD__ANNUITY':'527.6666666666666',
# 'AMT_GOODS_PRICE':'509.6666666666667',
# 'CLOSED_DAYS_CREDIT_MAX':'490.0',
# 'INSTAL_DBD_SUM':'486.6666666666667',
# 'AAAX_CREDIT_ANNUITY__SOURCE_MEAN':'481.3333333333333',
# 'PREV_CNT_PAYMENT_MEAN':'481.0',
# 'AAAX_CREDIT_ANNUITY__SOURCE_2':'479.3333333333333',
# 'AA_SOURCES':'474.3333333333333',
# 'AA_SCORES_STD':'467.0',
# 'AAO_PHONE__EMPLOYED':'463.6666666666667',
# 'CLOSED_DAYS_CREDIT_ENDDATE_MAX':'462.6666666666667',
# 'AAAX_CREDIT_ANNUITY__BIRTH':'461.3333333333333',
# 'IAO_PAYMENT__ANNUITY':'455.6666666666667',
# 'BURO_DAYS_CREDIT_MAX':'452.6666666666667',
# 'AAAO_SOURCES_MEAN__EMPLOYED_BIRTH':'447.6666666666667',
# 'BURO_DAYS_CREDIT_ENDDATE_MAX':'433.3333333333333',
# 'AAAX_CREDIT_ANNUITY__EMPLOYED':'428.6666666666667',
# 'INSTAL_AMT_PAYMENT_MIN':'426.3333333333333',
# 'ACTIVE_DAYS_CREDIT_UPDATE_MEAN':'425.6666666666667',
# 'INSTAL_DBD_MEAN':'424.3333333333333',
# 'PAO_ANNUNITY':'423.0',
# 'CLOSED_DAYS_CREDIT_VAR':'422.6666666666667',
# 'PREV_APPROVED_DAYS_DECISION_MAX':'412.0',
# 'POS_NAME_CONTRACT_STATUS_Active_MEAN':'411.0',
# 'AAAX_CREDIT_ANNUITY__SOURCE_1':'407.6666666666667',
# 'DAYS_EMPLOYED':'401.3333333333333',
# 'INSTAL_DBD_MAX':'401.3333333333333',
# 'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN':'397.3333333333333',
# 'BAO_CREDIT__INC':'393.3333333333333',
# 'INSTAL_DAYS_ENTRY_PAYMENT_MAX':'385.6666666666667',
# 'AAO_EMPLOYED__BIRTH':'382.6666666666667',
# 'BURO_AMT_CREDIT_MAX_OVERDUE_MEAN':'379.0',
# 'AAO_CREDIT__INC':'375.6666666666667',
# 'PREV_O_APP__CREDIT_VAR':'368.6666666666667',
# 'ACTIVE_DAYS_CREDIT_ENDDATE_MAX':'368.3333333333333',
# 'IBO_PAYMENT__ACREDIT':'360.3333333333333',
# 'CLOSED_AMT_CREDIT_SUM_MEAN':'359.3333333333333',
# 'POS_MONTHS_BALANCE_SIZE':'356.0',
# 'POS_MONTHS_BALANCE_MEAN':'355.3333333333333',
# 'PREV_O_APP__CREDIT_MEAN':'355.0',
# 'ACTIVE_DAYS_CREDIT_MEAN':'349.3333333333333',
# 'PREV_APPROVED_CNT_PAYMENT_SUM':'349.0',
# 'PREV_APPROVED_O_APP__CREDIT_VAR':'347.0',
# 'AMT_CREDIT':'346.0',
# 'BURO_AMT_CREDIT_SUM_MEAN':'342.3333333333333',
# 'INSTAL_DAYS_ENTRY_PAYMENT_MEAN':'340.3333333333333',
# 'INSTAL_AMT_INSTALMENT_MAX':'339.0',
# 'BURO_DAYS_CREDIT_MEAN':'338.0',
# 'CLOSED_AMT_CREDIT_SUM_SUM':'336.3333333333333',
# 'AAO_PHONE__BIRTH':'335.3333333333333',
# 'PREV_DAYS_DECISION_MAX':'335.0',
# 'CODE_GENDER':'333.6666666666667',
# 'INSTAL_PAYMENT_DIFF_MAX':'333.3333333333333',
# 'BURO_DAYS_CREDIT_VAR':'331.6666666666667',
# 'IBM_DPD_CREDIT_MAX_OVERDUE':'330.6666666666667',
# 'PREV_O_APP__CREDIT_MIN':'329.3333333333333',
# 'IAO_PAYMENT__INC':'329.3333333333333',
# 'BURO_DAYS_CREDIT_ENDDATE_MEAN':'328.3333333333333',
# 'PAO_ANNUNITY__CREDIT':'326.3333333333333',
# 'AAO_CAR__EMPLOY':'326.3333333333333',
# 'ACTIVE_DAYS_CREDIT_VAR':'320.6666666666667',
# 'INSTAL_DPD_MEAN':'320.3333333333333',
# 'AAO_CAR__BIRTH':'316.3333333333333',
# 'INSTAL_PAYMENT_DIFF_MEAN':'316.3333333333333',
# 'ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN':'313.6666666666667',
# 'BURO_AMT_CREDIT_SUM_DEBT_MEAN':'309.6666666666667',
# 'BURO_AMT_CREDIT_SUM_MAX':'306.3333333333333',
# 'PAO_ANNUNITY__INC':'303.6666666666667',
# 'ACTIVE_AMT_CREDIT_SUM_SUM':'303.0',
# 'BURO_AMT_CREDIT_SUM_SUM':'302.3333333333333',
# 'INSTAL_PAYMENT_PERC_MEAN':'298.0',
# 'PREV_HOUR_APPR_PROCESS_START_MEAN':'297.3333333333333',
# 'DAYS_LAST_PHONE_CHANGE':'297.0',
# 'INSTAL_DAYS_ENTRY_PAYMENT_SUM':'295.6666666666667',
# 'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN':'292.0',
# 'INSTAL_AMT_PAYMENT_MAX':'290.3333333333333',
# 'PREV_NAME_YIELD_GROUP_high_MEAN':'289.3333333333333',
# 'IBO_PAYMENT__CCREDIT':'284.0',
# 'INSTAL_AMT_PAYMENT_MEAN':'282.6666666666667',
# 'AAO_INC__FM':'281.3333333333333',
# 'POS_MONTHS_BALANCE_MAX':'280.3333333333333',
# 'CLOSED_AMT_CREDIT_SUM_MAX':'280.3333333333333',
# 'PREV_AMT_ANNUITY_MIN':'278.0',
# 'PREV_DAYS_DECISION_MEAN':'277.6666666666667',
# 'PREV_APPROVED_AMT_DOWN_PAYMENT_MAX':'277.3333333333333',
# 'POS_SK_DPD_DEF_MEAN':'277.3333333333333',
# 'CLOSED_DAYS_CREDIT_UPDATE_MEAN':'277.0',
# 'ACTIVE_AMT_CREDIT_SUM_MEAN':'274.3333333333333',
# 'ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN':'271.3333333333333',
# 'PREV_REFUSED_DAYS_DECISION_MAX':'270.6666666666667',
# 'POS_NAME_CONTRACT_STATUS_Completed_MEAN':'270.6666666666667',
# 'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN':'267.0',
# 'CC_CNT_DRAWINGS_ATM_CURRENT_MEAN':'264.3333333333333',
# 'PREV_APPROVED_HOUR_APPR_PROCESS_START_MEAN':'264.0',
# 'BURO_DAYS_CREDIT_UPDATE_MEAN':'262.6666666666667',
# 'ACTIVE_DAYS_CREDIT_MIN':'261.3333333333333',
# 'PREV_APPROVED_DAYS_DECISION_MEAN':'260.3333333333333',
# 'OWN_CAR_AGE':'256.0',
# 'BURO_DAYS_CREDIT_MIN':'251.66666666666666',
# 'PREV_APPROVED_O_APP__CREDIT_MEAN':'251.0',
# 'PREV_NAME_TYPE_SUITE_nan_MEAN':'244.66666666666666',
# 'PREV_APPROVED_AMT_CREDIT_MIN':'243.0',
# 'PREV_APPROVED_O_APP__CREDIT_MIN':'242.33333333333334',
# 'ACTIVE_AMT_CREDIT_SUM_MAX':'238.33333333333334',
# 'PAO_CREDIT__INC':'236.66666666666666',
# 'CLOSED_DAYS_CREDIT_ENDDATE_MEAN':'236.66666666666666',
# 'PREV_AMT_ANNUITY_MEAN':'234.66666666666666',
# 'PREV_DAYS_DECISION_MIN':'231.66666666666666',
# 'BURO_STATUS_0_MEAN_MEAN':'229.0',
# 'PREV_APPROVED_AMT_ANNUITY_MIN':'229.0',
# 'NAME_FAMILY_STATUS_Married':'228.0',
# 'PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN':'227.66666666666666',
# 'PREV_APPROVED_AMT_ANNUITY_MEAN':'226.0',
# 'INSTAL_AMT_INSTALMENT_MEAN':'225.0',
# 'ACTIVE_AMT_CREDIT_SUM_DEBT_SUM':'225.0',
# 'BURO_DAYS_CREDIT_ENDDATE_MIN':'224.33333333333334',
# 'PREV_APPROVED_DAYS_DECISION_MIN':'224.33333333333334',
# 'PAO_CREDIT__ANNUNITY':'223.33333333333334',
# 'PREV_AMT_DOWN_PAYMENT_MAX':'222.33333333333334',
# 'PREV_RATE_DOWN_PAYMENT_MEAN':'222.33333333333334',
# 'HOUR_APPR_PROCESS_START':'220.66666666666666',
# 'PREV_AMT_DOWN_PAYMENT_MEAN':'219.33333333333334',
# 'CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN':'216.0',
# 'PREV_NAME_YIELD_GROUP_middle_MEAN':'216.0',
# 'PREV_APPROVED_O_APP__CREDIT_MAX':'215.0',
# 'CLOSED_DAYS_CREDIT_MEAN':'214.33333333333334',
# 'PREV_APPROVED_AMT_GOODS_PRICE_MIN':'214.0',
# 'INSTAL_PAYMENT_DIFF_SUM':'213.0',
# 'PREV_O_APP__CREDIT_MAX':'213.0',
# 'PREV_NAME_CONTRACT_STATUS_Refused_MEAN':'212.0',
# 'CLOSED_DAYS_CREDIT_ENDDATE_MIN':'212.0',
# 'TOTALAREA_MODE':'209.66666666666666',
# 'PAO_CREDIT__GOODS':'205.0',
# 'BURO_CREDIT_TYPE_Credit card_MEAN':'203.66666666666666',
# 'BURO_AMT_CREDIT_SUM_DEBT_MAX':'202.66666666666666',
# 'AMT_INCOME_TOTAL':'201.0',
# 'AA_BY_NAME_EDUCATION_TYPE_AMT_INCOME_TOTAL_MEDIAN':'201.0',
# 'ACTIVE_AMT_CREDIT_SUM_DEBT_MAX':'198.33333333333334',
# 'INSTAL_PAYMENT_PERC_VAR':'198.0',
# 'AAO_INC__CHLD':'197.33333333333334',
# 'PREV_AMT_ANNUITY_MAX':'197.33333333333334',
# 'REGION_RATING_CLIENT_W_CITY':'196.33333333333334',
# 'PREV_APPROVED_AMT_CREDIT_MAX':'193.66666666666666',
# 'PREV_AMT_GOODS_PRICE_MIN':'193.66666666666666',
# 'PREV_NAME_YIELD_GROUP_low_normal_MEAN':'192.66666666666666',
# 'BAO_CREDIT__GOODS':'192.66666666666666',
# 'CLOSED_DAYS_CREDIT_MIN':'192.33333333333334',
# 'CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN':'189.0',
# 'PREV_APPROVED_AMT_ANNUITY_MAX':'188.66666666666666',
# 'CC_CNT_DRAWINGS_CURRENT_VAR':'188.66666666666666',
# 'INSTAL_AMT_PAYMENT_SUM':'188.33333333333334',
# 'INSTAL_PAYMENT_PERC_SUM':'187.33333333333334',
# 'BURO_CREDIT_ACTIVE_Closed_MEAN':'187.33333333333334',
# 'PREV_CNT_PAYMENT_SUM':'186.33333333333334',
# 'PREV_RATE_DOWN_PAYMENT_MAX':'184.33333333333334',
# 'BURO_CREDIT_TYPE_Consumer credit_MEAN':'184.33333333333334',
# 'PREV_APPROVED_AMT_APPLICATION_MIN':'181.0',
# 'PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN':'179.33333333333334',
# 'PAO_CREDIT__CREDIT':'178.33333333333334',
# 'PREV_NAME_YIELD_GROUP_low_action_MEAN':'177.33333333333334',
# 'BURO_AMT_CREDIT_SUM_DEBT_SUM':'177.33333333333334',
# 'CC_CNT_DRAWINGS_CURRENT_MEAN':'175.66666666666666',
# 'INSTAL_AMT_INSTALMENT_SUM':'174.33333333333334',
# 'PREV_APPROVED_RATE_DOWN_PAYMENT_MAX':'173.0',
# 'BURO_CREDIT_TYPE_Microloan_MEAN':'171.33333333333334',
# 'INSTAL_PAYMENT_DIFF_VAR':'171.33333333333334',
# 'BAO_CREDIT__ANNUNITY':'170.33333333333334',
# 'BAO_CREDIT__CREDIT':'169.66666666666666',
# 'PREV_APPROVED_AMT_DOWN_PAYMENT_MEAN':'168.33333333333334',
# 'PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN':'167.33333333333334',
# 'DEF_30_CNT_SOCIAL_CIRCLE':'167.0',
# 'PREV_REFUSED_AMT_CREDIT_MIN':'166.0',
# 'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN':'165.0',
# 'PREV_AMT_CREDIT_MEAN':'163.33333333333334',
# 'FLAG_WORK_PHONE':'163.0',
# 'PREV_AMT_APPLICATION_MEAN':'162.0',
# 'PREV_NAME_CONTRACT_STATUS_Approved_MEAN':'161.33333333333334',
# 'ACTIVE_MONTHS_BALANCE_SIZE_MEAN':'161.33333333333334',
# 'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN':'160.0',
# 'BURO_AMT_CREDIT_SUM_LIMIT_MEAN':'158.66666666666666',
# 'PREV_APPROVED_RATE_DOWN_PAYMENT_MEAN':'157.66666666666666',
# 'PREV_NAME_PAYMENT_TYPE_XNA_MEAN':'157.0',
# 'PREV_NAME_YIELD_GROUP_XNA_MEAN':'156.66666666666666',
# 'PREV_NAME_CLIENT_TYPE_New_MEAN':'155.33333333333334',
# 'CC_CNT_DRAWINGS_ATM_CURRENT_VAR':'153.66666666666666',
# 'CC_AMT_PAYMENT_CURRENT_MEAN':'152.33333333333334',
# 'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN':'151.66666666666666',
# 'BURO_CREDIT_TYPE_Mortgage_MEAN':'151.33333333333334',
# 'PREV_REFUSED_DAYS_DECISION_MEAN':'151.0',
# 'PREV_REFUSED_DAYS_DECISION_MIN':'150.0',
# 'PREV_AMT_CREDIT_MIN':'148.66666666666666',
# 'BURO_CREDIT_ACTIVE_Active_MEAN':'148.0',
# 'PREV_AMT_CREDIT_MAX':'147.33333333333334',
# 'PREV_RATE_DOWN_PAYMENT_MIN':'146.0',
# 'PREV_AMT_GOODS_PRICE_MEAN':'145.33333333333334',
# 'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN':'143.66666666666666',
# 'PREV_REFUSED_O_APP__CREDIT_MIN':'143.0',
# 'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN':'141.33333333333334',
# 'INSTAL_DPD_MAX':'140.0',
# 'YEARS_BEGINEXPLUATATION_MEDI':'138.33333333333334',
# 'PREV_APPROVED_AMT_APPLICATION_MAX':'138.33333333333334',
# 'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN':'138.0',
# 'INSTAL_COUNT':'137.33333333333334',
# 'PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN':'137.0',
# 'PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN':'136.66666666666666',
# 'INSTAL_DPD_SUM':'136.33333333333334',
# 'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN':'136.0',
# 'PREV_APPROVED_HOUR_APPR_PROCESS_START_MAX':'135.66666666666666',
# 'YEARS_BEGINEXPLUATATION_MODE':'135.33333333333334',
# 'PREV_CHANNEL_TYPE_Country-wide_MEAN':'134.66666666666666',
# 'BURO_STATUS_1_MEAN_MEAN':'134.33333333333334',
# 'PREV_REFUSED_HOUR_APPR_PROCESS_START_MEAN':'133.0',
# 'PREV_NAME_PRODUCT_TYPE_walk-in_MEAN':'133.0',
# 'PREV_APPROVED_AMT_APPLICATION_MEAN':'131.0',
# 'CLOSED_MONTHS_BALANCE_SIZE_MEAN':'128.66666666666666',
# 'APARTMENTS_MODE':'128.66666666666666',
# 'BURO_STATUS_C_MEAN_MEAN':'127.33333333333333',
# 'PREV_HOUR_APPR_PROCESS_START_MAX':'127.33333333333333',
# 'YEARS_BEGINEXPLUATATION_AVG':'126.66666666666667',
# 'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN':'126.66666666666667',
# 'AA_DOC_IND_KURT':'125.66666666666667',
# 'PREV_REFUSED_AMT_ANNUITY_MIN':'125.0',
# 'PREV_NAME_TYPE_SUITE_Family_MEAN':'125.0',
# 'PREV_APPROVED_AMT_GOODS_PRICE_MEAN':'124.66666666666667',
# 'PREV_APPROVED_AMT_CREDIT_MEAN':'124.33333333333333',
# 'PREV_NAME_PRODUCT_TYPE_x-sell_MEAN':'123.0',
# 'PREV_CHANNEL_TYPE_Stone_MEAN':'122.33333333333333',
# 'PREV_PRODUCT_COMBINATION_POS household with interest_MEAN':'121.0',
# 'BURO_STATUS_X_MEAN_MEAN':'120.0',
# 'BURO_MONTHS_BALANCE_SIZE_SUM':'119.33333333333333',
# 'PREV_AMT_APPLICATION_MAX':'118.0',
# 'PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN':'117.66666666666667',
# 'PREV_REFUSED_CNT_PAYMENT_MEAN':'116.66666666666667',
# 'CLOSED_AMT_ANNUITY_MAX':'116.66666666666667',
# 'PREV_NAME_CLIENT_TYPE_Repeater_MEAN':'116.33333333333333',
# 'LANDAREA_AVG':'116.0',
# 'BURO_MONTHS_BALANCE_SIZE_MEAN':'115.66666666666667',
# 'POS_SK_DPD_MEAN':'115.0',
# 'APARTMENTS_AVG':'115.0',
# 'PREV_NAME_CONTRACT_STATUS_Canceled_MEAN':'115.0',
# 'LIVINGAREA_AVG':'114.33333333333333',
# 'PREV_NAME_PRODUCT_TYPE_XNA_MEAN':'111.33333333333333',
# 'CLOSED_MONTHS_BALANCE_SIZE_SUM':'111.33333333333333',
# 'INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE':'110.66666666666667',
# 'BASEMENTAREA_MODE':'109.66666666666667',
# 'ORGANIZATION_TYPE_Self-employed':'109.33333333333333',
# 'BURO_CREDIT_TYPE_Car loan_MEAN':'108.66666666666667',
# 'BURO_AMT_ANNUITY_MEAN':'108.66666666666667',
# 'PREV_REFUSED_O_APP__CREDIT_MEAN':'108.33333333333333',
# 'CC_AMT_DRAWINGS_ATM_CURRENT_MEAN':'108.33333333333333',
# 'PREV_REFUSED_O_APP__CREDIT_VAR':'107.66666666666667',
# 'PREV_APPROVED_AMT_DOWN_PAYMENT_MIN':'107.66666666666667',
# 'PREV_REFUSED_AMT_GOODS_PRICE_MEAN':'106.0',
# 'PREV_NAME_GOODS_CATEGORY_Mobile_MEAN':'105.66666666666667',
# 'POS_SK_DPD_DEF_MAX':'105.33333333333333',
# 'OBS_60_CNT_SOCIAL_CIRCLE':'104.66666666666667',
# 'PREV_APPROVED_HOUR_APPR_PROCESS_START_MIN':'104.0',
# 'BASEMENTAREA_AVG':'104.0',
# 'NONLIVINGAREA_AVG':'103.66666666666667',
# 'PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN':'103.66666666666667',
# 'LIVINGAREA_MODE':'103.33333333333333',
# 'APARTMENTS_MEDI':'103.0',
# 'REG_CITY_NOT_LIVE_CITY':'102.0',
# 'OBS_30_CNT_SOCIAL_CIRCLE':'101.66666666666667',
# 'PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN':'100.66666666666667',
# 'ACTIVE_MONTHS_BALANCE_SIZE_SUM':'100.33333333333333',
# 'DEF_60_CNT_SOCIAL_CIRCLE':'100.33333333333333',
# 'PREV_AMT_DOWN_PAYMENT_MIN':'100.0',
# 'LANDAREA_MEDI':'99.66666666666667',
# 'CC_AMT_PAYMENT_CURRENT_SUM':'99.0',
# 'CC_AMT_DRAWINGS_ATM_CURRENT_SUM':'98.33333333333333',
# 'PREV_AMT_APPLICATION_MIN':'98.33333333333333',
# 'PREV_CODE_REJECT_REASON_SCO_MEAN':'98.0',
# 'PREV_REFUSED_CNT_PAYMENT_SUM':'98.0',
# 'LANDAREA_MODE':'97.0',
# 'BURO_AMT_CREDIT_SUM_OVERDUE_MEAN':'95.0',
# 'PREV_APPROVED_RATE_DOWN_PAYMENT_MIN':'94.66666666666667',
# 'CC_AMT_CREDIT_LIMIT_ACTUAL_SUM':'94.33333333333333',
# 'CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN':'94.33333333333333',
# 'CC_AMT_PAYMENT_CURRENT_VAR':'94.0',
# 'ACTIVE_AMT_ANNUITY_MAX':'94.0',
# 'PREV_CODE_REJECT_REASON_XAP_MEAN':'93.66666666666667',
# 'PREV_APPROVED_AMT_GOODS_PRICE_MAX':'93.33333333333333',
# 'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN':'93.33333333333333',
# 'AMT_REQ_CREDIT_BUREAU_QRT':'93.33333333333333',
# 'LIVINGAREA_MEDI':'93.0',
# 'PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN':'91.0',
# 'PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN':'90.66666666666667',
# 'PREV_REFUSED_AMT_ANNUITY_MAX':'90.0',
# 'NONLIVINGAREA_MODE':'89.66666666666667',
# 'POS_NAME_CONTRACT_STATUS_Signed_MEAN':'89.66666666666667',
# 'PREV_NAME_PORTFOLIO_Cash_MEAN':'88.66666666666667',
# 'ACTIVE_AMT_ANNUITY_MEAN':'88.66666666666667',
# 'YEARS_BUILD_MODE':'88.66666666666667',
# 'PREV_REFUSED_AMT_ANNUITY_MEAN':'87.0',
# 'AMT_REQ_CREDIT_BUREAU_YEAR':'86.66666666666667',
# 'PREV_CHANNEL_TYPE_Contact center_MEAN':'85.66666666666667',
# 'CC_AMT_CREDIT_LIMIT_ACTUAL_VAR':'85.0',
# 'COMMONAREA_MEDI':'84.0',
# 'PREV_NAME_PORTFOLIO_POS_MEAN':'83.66666666666667',
# 'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN':'83.66666666666667',
# 'PREV_NAME_GOODS_CATEGORY_Computers_MEAN':'83.33333333333333',
# 'PREV_REFUSED_O_APP__CREDIT_MAX':'83.0',
# 'POS_COUNT':'83.0',
# 'PREV_REFUSED_AMT_CREDIT_MAX':'83.0',
# 'PREV_REFUSED_AMT_APPLICATION_MIN':'82.66666666666667',
# 'ACTIVE_MONTHS_BALANCE_MIN_MIN':'82.33333333333333',
# 'PREV_NAME_SELLER_INDUSTRY_XNA_MEAN':'81.66666666666667',
# 'ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM':'81.0',
# 'BURO_AMT_ANNUITY_MAX':'81.0',
# 'PREV_NAME_PORTFOLIO_XNA_MEAN':'81.0',
# 'ORGANIZATION_TYPE_Business Entity Type 3':'81.0',
# 'BURO_AMT_CREDIT_SUM_LIMIT_SUM':'80.66666666666667',
# 'PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN':'80.66666666666667',
# 'PREV_REFUSED_HOUR_APPR_PROCESS_START_MIN':'78.66666666666667',
# 'PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN':'78.66666666666667',
# 'PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN':'78.33333333333333',
# 'ORGANIZATION_TYPE_Military':'78.0',
# 'PREV_REFUSED_HOUR_APPR_PROCESS_START_MAX':'77.66666666666667',
# 'PREV_NAME_GOODS_CATEGORY_XNA_MEAN':'77.0',
# 'PREV_REFUSED_AMT_GOODS_PRICE_MIN':'77.0',
# 'FLAG_DOCUMENT_3':'76.66666666666667',
# 'CC_AMT_INST_MIN_REGULARITY_VAR':'76.66666666666667',
# 'ENTRANCES_AVG':'76.33333333333333',
# 'PREV_CODE_REJECT_REASON_HC_MEAN':'76.33333333333333',
# 'ORGANIZATION_TYPE_Construction':'76.33333333333333',
# 'PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN':'75.66666666666667',
# 'BURO_MONTHS_BALANCE_MIN_MIN':'75.33333333333333',
# 'ORGANIZATION_TYPE_Transport: type 3':'75.0',
# 'POS_SK_DPD_MAX':'74.66666666666667',
# 'PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN':'74.66666666666667',
# 'PREV_HOUR_APPR_PROCESS_START_MIN':'74.33333333333333',
# 'PREV_REFUSED_AMT_CREDIT_MEAN':'74.0',
# 'PREV_REFUSED_AMT_APPLICATION_MEAN':'74.0',
# 'PREV_AMT_GOODS_PRICE_MAX':'73.66666666666667',
# 'PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN':'73.0',
# 'CLOSED_AMT_ANNUITY_MEAN':'73.0',
# 'COMMONAREA_AVG':'72.0',
# 'CC_AMT_DRAWINGS_CURRENT_MEAN':'71.33333333333333',
# 'CC_AMT_PAYMENT_CURRENT_MAX':'70.66666666666667',
# 'COMMONAREA_MODE':'70.33333333333333',
# 'CC_AMT_DRAWINGS_ATM_CURRENT_MAX':'70.0',
# 'CC_CNT_DRAWINGS_CURRENT_MAX':'70.0',
# 'CC_AMT_BALANCE_MEAN':'68.66666666666667',
# 'CC_AMT_RECEIVABLE_PRINCIPAL_MEAN':'68.0',
# 'BASEMENTAREA_MEDI':'66.33333333333333',
# 'NAME_INCOME_TYPE_Working':'65.33333333333333',
# 'NONLIVINGAREA_MEDI':'65.0',
# 'CLOSED_MONTHS_BALANCE_MIN_MIN':'64.0',
# 'CC_CNT_DRAWINGS_POS_CURRENT_MEAN':'64.0',
# 'ORGANIZATION_TYPE_School':'63.666666666666664',
# 'PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN':'63.333333333333336',
# 'CC_AMT_DRAWINGS_ATM_CURRENT_VAR':'63.333333333333336',
# 'ORGANIZATION_TYPE_Industry: type 9':'63.333333333333336',
# 'CC_AMT_PAYMENT_CURRENT_MIN':'63.333333333333336',
# 'PREV_PRODUCT_COMBINATION_Cash_MEAN':'63.333333333333336',
# 'CC_AMT_RECIVABLE_MEAN':'62.666666666666664',
# 'CC_AMT_DRAWINGS_CURRENT_VAR':'62.666666666666664',
# 'CC_AMT_DRAWINGS_CURRENT_SUM':'60.666666666666664',
# 'PREV_REFUSED_AMT_APPLICATION_MAX':'60.333333333333336',
# 'CC_AMT_PAYMENT_TOTAL_CURRENT_VAR':'60.333333333333336',
# 'CC_AMT_PAYMENT_TOTAL_CURRENT_SUM':'59.0',
# 'PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN':'58.333333333333336',
# 'LIVINGAPARTMENTS_MEDI':'58.0',
# 'PREV_NAME_GOODS_CATEGORY_Furniture_MEAN':'58.0',
# 'OCCUPATION_TYPE_Core staff':'57.666666666666664',
# 'CC_AMT_DRAWINGS_POS_CURRENT_SUM':'57.333333333333336',
# 'NAME_INCOME_TYPE_State servant':'57.333333333333336',
# 'LIVINGAPARTMENTS_MODE':'57.0',
# 'CC_SK_DPD_DEF_MEAN':'56.333333333333336',
# 'PREV_NAME_PORTFOLIO_Cards_MEAN':'56.333333333333336',
# 'CC_AMT_RECIVABLE_VAR':'56.333333333333336',
# 'LIVINGAPARTMENTS_AVG':'55.666666666666664',
# 'CC_AMT_BALANCE_MAX':'55.0',
# 'CC_CNT_DRAWINGS_CURRENT_SUM':'55.0',
# 'OCCUPATION_TYPE_Drivers':'53.333333333333336',
# 'YEARS_BUILD_MEDI':'52.666666666666664',
# 'PREV_REFUSED_AMT_GOODS_PRICE_MAX':'52.666666666666664',
# 'CC_CNT_DRAWINGS_ATM_CURRENT_SUM':'51.333333333333336',
# 'CC_AMT_DRAWINGS_POS_CURRENT_MAX':'50.333333333333336',
# 'CC_CNT_DRAWINGS_POS_CURRENT_MAX':'50.0',
# 'CC_AMT_BALANCE_MIN':'50.0',
# 'PREV_CHANNEL_TYPE_Regional / Local_MEAN':'49.666666666666664',
# 'YEARS_BUILD_AVG':'49.333333333333336',
# 'PREV_CODE_REJECT_REASON_LIMIT_MEAN':'49.0',
# 'WALLSMATERIAL_MODE_Stone, brick':'48.666666666666664',
# 'CC_AMT_PAYMENT_TOTAL_CURRENT_MAX':'48.666666666666664',
# 'POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN':'48.666666666666664',
# 'CC_AMT_DRAWINGS_POS_CURRENT_VAR':'48.333333333333336',
# 'OCCUPATION_TYPE_High skill tech staff':'48.0',
# 'FLAG_DOCUMENT_8':'46.666666666666664',
# 'ENTRANCES_MEDI':'46.0',
# 'PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN':'46.0',
# 'CC_CNT_DRAWINGS_POS_CURRENT_VAR':'46.0',
# 'CC_AMT_DRAWINGS_CURRENT_MAX':'45.666666666666664',
# 'CC_AMT_RECEIVABLE_PRINCIPAL_MAX':'45.333333333333336',
# 'FLOORSMIN_AVG':'45.333333333333336',
# 'PREV_REFUSED_RATE_DOWN_PAYMENT_MAX':'45.0',
# 'ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN':'44.333333333333336',
# 'CC_AMT_BALANCE_VAR':'43.666666666666664',
# 'NAME_HOUSING_TYPE_Office apartment':'43.666666666666664',
# 'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN':'43.333333333333336',
# 'CNT_FAM_MEMBERS':'43.333333333333336',
# 'PREV_PRODUCT_COMBINATION_Card Street_MEAN':'43.0',
# 'AA_LIVE_IND_SUM':'42.333333333333336',
# 'ENTRANCES_MODE':'42.0',
# 'FLOORSMAX_AVG':'41.666666666666664',
# 'WEEKDAY_APPR_PROCESS_START_MONDAY':'41.333333333333336',
# 'CC_AMT_INST_MIN_REGULARITY_SUM':'40.0',
# 'CC_AMT_CREDIT_LIMIT_ACTUAL_MIN':'39.0',
# 'INSTAL_PAYMENT_PERC_MAX':'37.333333333333336',
# 'BURO_CREDIT_ACTIVE_Sold_MEAN':'37.0',
# 'PREV_PRODUCT_COMBINATION_POS household without interest_MEAN':'37.0',
# 'PREV_REFUSED_RATE_DOWN_PAYMENT_MIN':'37.0',
# 'PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN':'37.0',
# 'OCCUPATION_TYPE_Laborers':'36.666666666666664',
# 'OCCUPATION_TYPE_Accountants':'36.333333333333336',
# 'AMT_REQ_CREDIT_BUREAU_MON':'36.0',
# 'CC_AMT_CREDIT_LIMIT_ACTUAL_MAX':'35.666666666666664',
# 'ORGANIZATION_TYPE_Bank':'35.333333333333336',
# 'CC_AMT_RECIVABLE_MAX':'34.666666666666664',
# 'PREV_REFUSED_AMT_DOWN_PAYMENT_MAX':'34.333333333333336',
# 'CC_AMT_INST_MIN_REGULARITY_MEAN':'34.333333333333336',
# 'LIVE_CITY_NOT_WORK_CITY':'34.0',
# 'NAME_EDUCATION_TYPE_Higher education':'33.666666666666664',
# 'CC_CNT_INSTALMENT_MATURE_CUM_MEAN':'33.666666666666664',
# 'CC_AMT_DRAWINGS_POS_CURRENT_MEAN':'33.333333333333336',
# 'CC_AMT_RECIVABLE_SUM':'33.333333333333336',
# 'CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN':'32.666666666666664',
# 'PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN':'32.333333333333336',
# 'FLOORSMIN_MEDI':'32.333333333333336',
# 'ELEVATORS_AVG':'32.0',
# 'CC_CNT_DRAWINGS_ATM_CURRENT_MAX':'32.0',
# 'PREV_NAME_SELLER_INDUSTRY_Construction_MEAN':'32.0',
# 'FLOORSMIN_MODE':'32.0',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN':'31.666666666666668',
# 'OCCUPATION_TYPE_Medicine staff':'31.666666666666668',
# 'CLOSED_AMT_CREDIT_SUM_DEBT_MAX':'31.333333333333332',
# 'NONLIVINGAPARTMENTS_AVG':'30.666666666666668',
# 'ORGANIZATION_TYPE_Security Ministries':'30.333333333333332',
# 'CC_MONTHS_BALANCE_VAR':'30.0',
# 'ACTIVE_MONTHS_BALANCE_MAX_MAX':'29.666666666666668',
# 'CC_CNT_INSTALMENT_MATURE_CUM_SUM':'29.666666666666668',
# 'CC_CNT_DRAWINGS_POS_CURRENT_SUM':'29.0',
# 'PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN':'29.0',
# 'FLAG_DOCUMENT_18':'28.333333333333332',
# 'PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN':'28.0',
# 'FLOORSMAX_MEDI':'28.0',
# 'PREV_REFUSED_RATE_DOWN_PAYMENT_MEAN':'27.666666666666668',
# 'CC_AMT_RECIVABLE_MIN':'27.666666666666668',
# 'CLOSED_AMT_CREDIT_SUM_DEBT_MEAN':'27.333333333333332',
# 'CC_CNT_INSTALMENT_MATURE_CUM_VAR':'27.333333333333332',
# 'ORGANIZATION_TYPE_Police':'27.333333333333332',
# 'CNT_CHILDREN':'27.333333333333332',
# 'REGION_RATING_CLIENT':'27.0',
# 'CC_AMT_BALANCE_SUM':'26.666666666666668',
# 'CC_NAME_CONTRACT_STATUS_Active_SUM':'26.666666666666668',
# 'CC_SK_DPD_SUM':'26.666666666666668',
# 'ORGANIZATION_TYPE_Medicine':'26.0',
# 'CLOSED_MONTHS_BALANCE_MAX_MAX':'25.666666666666668',
# 'OCCUPATION_TYPE_Sales staff':'25.333333333333332',
# 'FLAG_PHONE':'24.666666666666668',
# 'PREV_PRODUCT_COMBINATION_POS other with interest_MEAN':'24.666666666666668',
# 'PREV_NAME_TYPE_SUITE_Children_MEAN':'24.333333333333332',
# 'PREV_NAME_TYPE_SUITE_Other_B_MEAN':'24.0',
# 'NAME_HOUSING_TYPE_House / apartment':'23.666666666666668',
# 'WEEKDAY_APPR_PROCESS_START_TUESDAY':'23.666666666666668',
# 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY':'23.333333333333332',
# 'CC_AMT_RECEIVABLE_PRINCIPAL_VAR':'23.333333333333332',
# 'CC_NAME_CONTRACT_STATUS_Signed_VAR':'23.0',
# 'NAME_HOUSING_TYPE_Municipal apartment':'23.0',
# 'PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN':'22.666666666666668',
# 'CC_MONTHS_BALANCE_MEAN':'22.333333333333332',
# 'FLOORSMAX_MODE':'22.333333333333332',
# 'PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN':'21.333333333333332',
# 'NAME_EDUCATION_TYPE_Secondary / secondary special':'21.333333333333332',
# 'NAME_FAMILY_STATUS_Single / not married':'21.0',
# 'NONLIVINGAPARTMENTS_MODE':'21.0',
# 'WEEKDAY_APPR_PROCESS_START_FRIDAY':'21.0',
# 'PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN':'20.666666666666668',
# 'PREV_CODE_REJECT_REASON_SCOFR_MEAN':'20.666666666666668',
# 'CC_AMT_RECEIVABLE_PRINCIPAL_MIN':'20.0',
# 'AAO_CHLD__FM':'20.0',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN':'19.666666666666668',
# 'CC_MONTHS_BALANCE_SUM':'19.666666666666668',
# 'CC_NAME_CONTRACT_STATUS_Active_VAR':'19.666666666666668',
# 'CC_AMT_RECEIVABLE_PRINCIPAL_SUM':'19.666666666666668',
# 'CC_NAME_CONTRACT_STATUS_Active_MEAN':'19.666666666666668',
# 'OCCUPATION_TYPE_Low-skill Laborers':'19.333333333333332',
# 'CC_SK_DPD_VAR':'19.333333333333332',
# 'CC_AMT_DRAWINGS_POS_CURRENT_MIN':'19.0',
# 'PREV_REFUSED_AMT_DOWN_PAYMENT_MIN':'19.0',
# 'CLOSED_AMT_CREDIT_SUM_DEBT_SUM':'18.333333333333332',
# 'CC_CNT_DRAWINGS_OTHER_CURRENT_VAR':'18.333333333333332',
# 'CC_AMT_TOTAL_RECEIVABLE_MEAN':'18.0',
# 'WEEKDAY_APPR_PROCESS_START_SATURDAY':'18.0',
# 'CC_AMT_INST_MIN_REGULARITY_MAX':'18.0',
# 'LIVE_REGION_NOT_WORK_REGION':'18.0',
# 'ORGANIZATION_TYPE_Kindergarten':'17.666666666666668',
# 'CC_SK_DPD_MEAN':'17.333333333333332',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN':'17.333333333333332',
# 'BURO_CREDIT_DAY_OVERDUE_MAX':'17.333333333333332',
# 'ELEVATORS_MODE':'17.333333333333332',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN':'17.0',
# 'NONLIVINGAPARTMENTS_MEDI':'16.666666666666668',
# 'AMT_REQ_CREDIT_BUREAU_WEEK':'16.333333333333332',
# 'CC_AMT_PAYMENT_TOTAL_CURRENT_MIN':'16.333333333333332',
# 'PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN':'16.0',
# 'PREV_NAME_SELLER_INDUSTRY_Industry_MEAN':'16.0',
# 'NAME_INCOME_TYPE_Commercial associate':'15.666666666666666',
# 'WEEKDAY_APPR_PROCESS_START_SUNDAY':'15.333333333333334',
# 'NAME_TYPE_SUITE_Unaccompanied':'15.333333333333334',
# 'WALLSMATERIAL_MODE_Panel':'15.333333333333334',
# 'NAME_TYPE_SUITE_Other_B':'15.0',
# 'CC_AMT_TOTAL_RECEIVABLE_MAX':'15.0',
# 'PREV_REFUSED_AMT_DOWN_PAYMENT_MEAN':'15.0',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN':'14.666666666666666',
# 'CC_AMT_DRAWINGS_CURRENT_MIN':'14.666666666666666',
# 'WALLSMATERIAL_MODE_Others':'14.666666666666666',
# 'AMT_REQ_CREDIT_BUREAU_DAY':'14.333333333333334',
# 'FLAG_OWN_REALTY':'14.333333333333334',
# 'CC_CNT_INSTALMENT_MATURE_CUM_MAX':'14.333333333333334',
# 'CC_AMT_TOTAL_RECEIVABLE_VAR':'14.0',
# 'PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN':'13.666666666666666',
# 'CLOSED_DEBT_CREDIT_RATIO':'13.666666666666666',
# 'PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN':'13.333333333333334',
# 'CC_CNT_DRAWINGS_POS_CURRENT_MIN':'13.333333333333334',
# 'PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN':'13.333333333333334',
# 'CC_AMT_TOTAL_RECEIVABLE_MIN':'13.0',
# 'REG_CITY_NOT_WORK_CITY':'13.0',
# 'CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN':'12.666666666666666',
# 'PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN':'12.666666666666666',
# 'PREV_NAME_TYPE_SUITE_Group of people_MEAN':'12.333333333333334',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN':'12.333333333333334',
# 'CC_AMT_DRAWINGS_OTHER_CURRENT_VAR':'12.333333333333334',
# 'NAME_TYPE_SUITE_Spouse, partner':'12.333333333333334',
# 'CC_NAME_CONTRACT_STATUS_Completed_MEAN':'12.0',
# 'CC_AMT_TOTAL_RECEIVABLE_SUM':'12.0',
# 'WEEKDAY_APPR_PROCESS_START_THURSDAY':'12.0',
# 'REG_REGION_NOT_WORK_REGION':'11.666666666666666',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN':'11.333333333333334',
# 'BURO_CREDIT_DAY_OVERDUE_MEAN':'11.333333333333334',
# 'FONDKAPREMONT_MODE_reg oper spec account':'11.333333333333334',
# 'CC_AMT_DRAWINGS_OTHER_CURRENT_MAX':'11.333333333333334',
# 'ORGANIZATION_TYPE_Trade: type 3':'11.0',
# 'BURO_STATUS_5_MEAN_MEAN':'11.0',
# 'ELEVATORS_MEDI':'10.666666666666666',
# 'BURO_STATUS_2_MEAN_MEAN':'10.333333333333334',
# 'BURO_CNT_CREDIT_PROLONG_SUM':'10.333333333333334',
# 'BURO_MONTHS_BALANCE_MAX_MAX':'10.333333333333334',
# 'PREV_CODE_REJECT_REASON_VERIF_MEAN':'9.666666666666666',
# 'NAME_FAMILY_STATUS_Separated':'9.666666666666666',
# 'POS_NAME_CONTRACT_STATUS_Approved_MEAN':'8.666666666666666',
# 'OCCUPATION_TYPE_Private service staff':'8.333333333333334',
# 'ACTIVE_CREDIT_DAY_OVERDUE_MAX':'8.333333333333334',
# 'NAME_TYPE_SUITE_Family':'8.333333333333334',
# 'CC_AMT_DRAWINGS_OTHER_CURRENT_SUM':'7.666666666666667',
# 'FLAG_DOCUMENT_11':'7.333333333333333',
# 'CC_MONTHS_BALANCE_MIN':'7.333333333333333',
# 'PREV_NAME_GOODS_CATEGORY_Gardening_MEAN':'7.333333333333333',
# 'NAME_CONTRACT_TYPE_Cash loans':'7.333333333333333',
# 'CC_COUNT':'7.333333333333333',
# 'CC_NAME_CONTRACT_STATUS_Completed_VAR':'7.0',
# 'NAME_FAMILY_STATUS_Civil marriage':'7.0',
# 'FLAG_DOCUMENT_16':'7.0',
# 'NAME_FAMILY_STATUS_Widow':'6.666666666666667',
# 'BURO_STATUS_4_MEAN_MEAN':'6.666666666666667',
# 'OCCUPATION_TYPE_Managers':'6.333333333333333',
# 'CC_SK_DPD_DEF_VAR':'6.333333333333333',
# 'PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN':'6.0',
# 'FLAG_OWN_CAR':'5.666666666666667',
# 'PREV_NAME_TYPE_SUITE_Other_A_MEAN':'5.333333333333333',
# 'CC_SK_DPD_MAX':'5.333333333333333',
# 'NAME_HOUSING_TYPE_Rented apartment':'4.666666666666667',
# 'HOUSETYPE_MODE_specific housing':'4.666666666666667',
# 'PREV_CODE_REJECT_REASON_CLIENT_MEAN':'4.666666666666667',
# 'CC_MONTHS_BALANCE_MAX':'4.666666666666667',
# 'ORGANIZATION_TYPE_Government':'4.666666666666667',
# 'ORGANIZATION_TYPE_Business Entity Type 1':'4.333333333333333',
# 'PREV_CODE_REJECT_REASON_XNA_MEAN':'4.333333333333333',
# 'CC_NAME_CONTRACT_STATUS_Signed_MEAN':'4.333333333333333',
# 'BURO_STATUS_3_MEAN_MEAN':'4.333333333333333',
# 'ORGANIZATION_TYPE_Industry: type 3':'4.333333333333333',
# 'CC_SK_DPD_DEF_SUM':'3.6666666666666665',
# 'CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN':'3.6666666666666665',
# 'ORGANIZATION_TYPE_Other':'3.6666666666666665',
# 'PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN':'3.6666666666666665',
# 'PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN':'3.0',
# 'ORGANIZATION_TYPE_Hotel':'3.0',
# 'ACTIVE_CNT_CREDIT_PROLONG_SUM':'3.0',
# 'ORGANIZATION_TYPE_Restaurant':'2.6666666666666665',
# 'ORGANIZATION_TYPE_Trade: type 7':'2.6666666666666665',
# 'FONDKAPREMONT_MODE_reg oper account':'2.6666666666666665',
# 'NAME_HOUSING_TYPE_With parents':'2.3333333333333335',
# 'CC_CNT_DRAWINGS_CURRENT_MIN':'2.3333333333333335',
# 'PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN':'2.3333333333333335',
# 'NAME_CONTRACT_TYPE_Revolving loans':'2.0',
# 'CLOSED_AMT_CREDIT_SUM_LIMIT_SUM':'2.0',
# 'PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN':'2.0',
# 'FLAG_EMAIL':'2.0',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN':'2.0',
# 'FLAG_DOCUMENT_6':'1.6666666666666667',
# 'CC_NAME_CONTRACT_STATUS_Active_MIN':'1.3333333333333333',
# 'WALLSMATERIAL_MODE_Block':'1.3333333333333333',
# 'ACTIVE_CREDIT_DAY_OVERDUE_MEAN':'1.3333333333333333',
# 'FONDKAPREMONT_MODE_not specified':'1.0',
# 'ORGANIZATION_TYPE_Transport: type 4':'1.0',
# 'CC_NAME_CONTRACT_STATUS_Completed_SUM':'1.0',
# 'CC_CNT_INSTALMENT_MATURE_CUM_MIN':'1.0',
# 'PREV_PRODUCT_COMBINATION_POS others without interest_MEAN':'0.6666666666666666',
# 'OCCUPATION_TYPE_Cleaning staff':'0.6666666666666666',
# 'CC_AMT_INST_MIN_REGULARITY_MIN':'0.6666666666666666',
# 'WALLSMATERIAL_MODE_Wooden':'0.3333333333333333',
# 'PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN':'0.3333333333333333',
# 'CLOSED_CNT_CREDIT_PROLONG_SUM':'0.3333333333333333',
# 'NAME_EDUCATION_TYPE_Incomplete higher':'0.3333333333333333',
# 'NAME_EDUCATION_TYPE_Lower secondary':'0.3333333333333333',
# 'FONDKAPREMONT_MODE_org spec account':'0.3333333333333333',
# 'NAME_TYPE_SUITE_Children':'0.3333333333333333',
# 'WALLSMATERIAL_MODE_Mixed':'0.3333333333333333',
# 'ORGANIZATION_TYPE_Security':'0.3333333333333333',
# 'HOUSETYPE_MODE_block of flats':'0.0',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN':'0.0',
# 'PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN':'0.0',
# 'CC_SK_DPD_DEF_MAX':'0.0',
# 'OCCUPATION_TYPE_Security staff':'0.0',
# 'CC_CNT_DRAWINGS_OTHER_CURRENT_MAX':'0.0',
# 'OCCUPATION_TYPE_Waiters/barmen staff':'0.0',
# 'REG_REGION_NOT_LIVE_REGION':'0.0',
# 'ORGANIZATION_TYPE_Electricity':'0.0',
# 'BURO_CREDIT_TYPE_Another type of loan_MEAN':'0.0',
