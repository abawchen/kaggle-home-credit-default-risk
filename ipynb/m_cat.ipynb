# %%
import datetime
import gc
import os
import time
import numpy as np
import pandas as pd
import json

from colorama import Fore, Style

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from bayes_opt import BayesianOptimization

from utils import ModelWrapper
from utils.preprocess import load_all
from utils.utils import (
    highlight_print, timer, submit, calculate_feature_importance, load_feats,
)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
def exp_feats(df):
    df['BAO_CREDIT__ANNUNITY'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_ANNUITY']
    df['BAO_CREDIT__INC'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_INCOME_TOTAL']
    df['BAO_CREDIT__CREDIT'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_CREDIT']
    df['BAO_CREDIT__GOODS'] = df['ACTIVE_AMT_CREDIT_SUM_SUM'] / df['AMT_GOODS_PRICE']
    
    df['PAO_CREDIT__ANNUNITY'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_ANNUITY']
    df['PAO_CREDIT__INC'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_INCOME_TOTAL']
    df['PAO_CREDIT__CREDIT'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_CREDIT']
    df['PAO_CREDIT__GOODS'] = df['PREV_AMT_CREDIT_MEAN'] / df['AMT_GOODS_PRICE']
    
    df['PAO_ANNUNITY'] = df['PREV_AMT_ANNUITY_MEAN'] / df['AMT_ANNUITY']
    df['PAO_ANNUNITY__INC'] = df['PREV_AMT_ANNUITY_MEAN'] / df['AMT_INCOME_TOTAL']
    df['PAO_ANNUNITY__CREDIT'] = df['PREV_AMT_ANNUITY_MEAN'] / df['AMT_CREDIT']
    
    df["IBO_PAYMENT__ACREDIT"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['ACTIVE_AMT_CREDIT_SUM_SUM']
    df["IBO_PAYMENT__CCREDIT"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['CLOSED_AMT_CREDIT_SUM_SUM']
    df["IAO_PAYMENT__ANNUITY"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['AMT_ANNUITY']
    df["IAO_PAYMENT__INC"] = df["INSTAL_AMT_PAYMENT_SUM"] / df['AMT_INCOME_TOTAL']
    
    return df

# %%
with timer('Load features'):
    df = load_all('../data/preprocess')
    print("df shape:", df.shape)
# Out:
# df shape: (356251, 951)
# [Done] Load features at 2018-08-27 17:29:58.483796

# %%
df_exp = df.copy()
df_exp = exp_feats(df)
print("df_exp shape:", df_exp.shape)
# Out:
# df_exp shape: (356251, 966)

# %%
df_full = df_exp.copy()

# %%
base = '91_m_lgbm5_best'
model_folder = os.path.join('..', 'expmodel', base)
feats = load_feats(model_folder, 'feats.json')
if feats is not None:
    print('Load feats from: {}'.format(base))
    drop_feats = list(set(df_full.columns) - set(feats))
else:
    skip_feats = ['TARGET', 'SK_ID_CURR', 'SK_ID_BUREAU', 'SK_ID_PREV', 'index'] + drop_feats
    feats = [f for f in df_full.columns if f not in skip_feats]
print('feats num: {}, drop_feats: {}'.format(len(feats), len(drop_feats)))
# Out:
# Load feats from: 91_m_lgbm5_best
# feats num: 696, drop_feats: 317

# %%
df_full, selected_generated_feats = process_generated_feats(df_full, feats)
df_full[feats]
print('df_full shape: {}, selected_generated_feats: {}'.format(
    df_full.shape, len(selected_generated_feats)))
df_gen = df_full.copy()
print('df_gen shape: {}, feats num: {}'.format(df_gen.shape, len(feats)))
# Out:
# /Users/ylchen/.virtualenvs/ml-playground/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: divide by zero encountered in true_divide
# /Users/ylchen/.virtualenvs/ml-playground/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# df_full shape: (356251, 1013), selected_generated_feats: 47

# %%
train_df = df_gen[df_gen['TARGET'].notnull()]
test_df = df_gen[df_gen['TARGET'].isnull()]
print("train_df shape:", train_df.shape)
print("test_df shape:", test_df.shape)

X_train = train_df[feats]
X_test = test_df[feats]
y_train = train_df['TARGET']
print("X_train df shape:", X_train.shape)
# Out:
# train_df shape: (307507, 1013)
# test_df shape: (48744, 1013)
# X_train df shape: (307507, 696)

# %%
def feature_importance(n_fold, clf, feats):
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = n_fold+1
    return fold_importance_df

# %%
import importlib
importlib.reload(ModelWrapper)

r = 1
nums_fold = 5
random_state = 1001
prefix = '106_{}_cat{}_{}'.format('m', nums_fold, str(r).zfill(2))
model_folder = os.path.join('..', 'expmodel', '{}'.format(prefix))
params = {}
params = {
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False,
    'verbose': True
}
params['iterations'] = 10000
params['depth'] = int(params['depth'])
params['verbose'] = True

fit_params = {}
fit_params = {
    'early_stopping_rounds': 200,
    'verbose': 1000,
}
model = ModelWrapper.ModelWrapper(
    CLF=CatBoostClassifier,
    name="CatBoost",
    model_folder=model_folder,
    feats=feats,
    drop_feats=drop_feats,
    params=params,
    fit_params=fit_params
)

# %%
n_fold = 0
random_state = 1001
feature_importance_df = pd.DataFrame()
folds = KFold(n_splits=nums_fold, shuffle=True, random_state=random_state)
for clf, fold_auc in model.folds_train(folds, X_train, y_train, X_test):
    highlight_print(Fore.LIGHTBLUE_EX, '- %.6f (%s)' % (fold_auc, datetime.datetime.now()))
    # fold_importance_df = feature_importance(n_fold, clf, feats)
    # feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    n_fold += 1
    del clf #, fold_importance_df
    gc.collect()
        
score = roc_auc_score(y_train, model.oof_preds_df)
highlight_print(Fore.RED, '## CatBoost: %.6f' % score)
model.scores.append(score)
model.serialize_scores()
# Out:
# feats num: 696
# model folder: ../expmodel/106_m_cat5_01
# - 0.785062 (2018-08-27 20:46:17.714025)
# - 0.782466 (2018-08-27 20:46:19.929661)
# - 0.785878 (2018-08-27 20:46:21.704855)
# - 0.784271 (2018-08-27 20:46:23.840220)
# - 0.785791 (2018-08-27 20:46:25.808593)
# ## CatBoost: 0.784571

# %%
"""
- 0.785062 (2018-08-27 20:46:17.714025)
- 0.782466 (2018-08-27 20:46:19.929661)
- 0.785878 (2018-08-27 20:46:21.704855)
- 0.784271 (2018-08-27 20:46:23.840220)
- 0.785791 (2018-08-27 20:46:25.808593)
## CatBoost: 0.784571
"""

# %%
n_iter = 5
n_splits = 5
prefix = '106_{}_cat{}_{}_{}'.format('bx', n_splits, n_iter, str(r).zfill(2))
model_folder = os.path.join('..', 'expmodel', prefix)

b_round = 0
b_feature_importance_df = pd.DataFrame()

def cat_evaluate(**params):
    warnings.simplefilter('ignore')

    global b_feature_importance_df
    global b_round

    params['n_estimators'] = 10000
    params['depth'] = int(params['depth'])
    params['bootstrap_type'] = 'Bernoulli'
    params['eval_metric'] = 'AUC'
    params['od_type'] = 'Iter'
    params['allow_writing_files'] = False
    params['verbose'] = True

    submodel_folder = os.path.join(model_folder, str(b_round))
    try:
        os.makedirs(submodel_folder)
    except:
        pass
    folds = KFold(n_splits=n_splits, shuffle=True, random_state=1001)
    # print(fit_params)
    b_model = ModelWrapper.ModelWrapper(
        CLF=CatBoostClassifier,
        name="CatBoost",
        model_folder=submodel_folder,
        feats=feats,
        drop_feats=drop_feats,
        params=params,
        fit_params=fit_params
    )
    n_fold = 0
    for clf, fold_auc in b_model.folds_train(folds, X_train, y_train, X_test):
        # fold_importance_df = feature_importance(n_fold, clf, feats)
        # b_feature_importance_df = pd.concat([b_feature_importance_df, fold_importance_df], axis=0)
        n_fold += 1
        del clf# , fold_importance_df
        gc.collect()

    score = roc_auc_score(y_train, b_model.oof_preds_df)
    b_model.scores.append(score)
    b_model.serialize_scores()
    b_round += 1
    return score

with timer("BayesianOptimization:"):
    b_params = {
        'learning_rate': (0.1, 0.5),
        'depth': (3, 6),
        'l2_leaf_reg': (38, 42),
        'subsample': (0.7, 1),
        'scale_pos_weight': (4.5, 5.5),
    }
    bo = BayesianOptimization(cat_evaluate, b_params)
    bo.maximize(init_points=5, n_iter=n_iter)
# Out:
# Initialization
# --------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |     depth |   l2_leaf_reg |   learning_rate |   scale_pos_weight |   subsample |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/0
# ../expmodel/106_bx_cat5_5_01/0/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7046939	best: 0.7046939 (0)	total: 773ms	remaining: 2h 8m 51s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.789184678
# bestIteration = 248
#
# Shrink model to first 249 iterations.
# ../expmodel/106_bx_cat5_5_01/0/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.6979556	best: 0.6979556 (0)	total: 841ms	remaining: 2h 20m 5s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.784194672
# bestIteration = 331
#
# Shrink model to first 332 iterations.
# ../expmodel/106_bx_cat5_5_01/0/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7005832	best: 0.7005832 (0)	total: 770ms	remaining: 2h 8m 14s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7873468973
# bestIteration = 325
#
# Shrink model to first 326 iterations.
# ../expmodel/106_bx_cat5_5_01/0/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.6980710	best: 0.6980710 (0)	total: 847ms	remaining: 2h 21m 10s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7855236555
# bestIteration = 357
#
# Shrink model to first 358 iterations.
# ../expmodel/106_bx_cat5_5_01/0/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.6948664	best: 0.6948664 (0)	total: 781ms	remaining: 2h 10m 7s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7890296137
# bestIteration = 285
#
# Shrink model to first 286 iterations.
#     1 | 40m42s |    0.78701 |    3.3064 |       41.4579 |          0.3302 |             5.1004 |      0.9097 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/1
# ../expmodel/106_bx_cat5_5_01/1/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7221515	best: 0.7221515 (0)	total: 1.27s	remaining: 3h 31m 25s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7888133164
# bestIteration = 263
#
# Shrink model to first 264 iterations.
# ../expmodel/106_bx_cat5_5_01/1/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.7156684	best: 0.7156684 (0)	total: 1.2s	remaining: 3h 19m 52s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7839010125
# bestIteration = 193
#
# Shrink model to first 194 iterations.
# ../expmodel/106_bx_cat5_5_01/1/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7159901	best: 0.7159901 (0)	total: 1.51s	remaining: 4h 12m 12s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7853199159
# bestIteration = 197
#
# Shrink model to first 198 iterations.
# ../expmodel/106_bx_cat5_5_01/1/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.7181164	best: 0.7181164 (0)	total: 1.17s	remaining: 3h 15m 28s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7866563792
# bestIteration = 169
#
# Shrink model to first 170 iterations.
# ../expmodel/106_bx_cat5_5_01/1/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.7191940	best: 0.7191940 (0)	total: 1.05s	remaining: 2h 54m 47s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7889642065
# bestIteration = 224
#
# Shrink model to first 225 iterations.
#     2 | 47m45s |    0.78670 |    5.0703 |       40.8905 |          0.2724 |             5.0086 |      0.8330 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/2
# ../expmodel/106_bx_cat5_5_01/2/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7057267	best: 0.7057267 (0)	total: 853ms	remaining: 2h 22m 4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7847044304
# bestIteration = 142
#
# Shrink model to first 143 iterations.
# ../expmodel/106_bx_cat5_5_01/2/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.6973764	best: 0.6973764 (0)	total: 997ms	remaining: 2h 46m 8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7808926988
# bestIteration = 243
#
# Shrink model to first 244 iterations.
# ../expmodel/106_bx_cat5_5_01/2/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7026010	best: 0.7026010 (0)	total: 943ms	remaining: 2h 37m 7s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7853263045
# bestIteration = 198
#
# Shrink model to first 199 iterations.
# ../expmodel/106_bx_cat5_5_01/2/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.6992342	best: 0.6992342 (0)	total: 775ms	remaining: 2h 9m 11s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7838280388
# bestIteration = 205
#
# Shrink model to first 206 iterations.
# ../expmodel/106_bx_cat5_5_01/2/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.6995328	best: 0.6995328 (0)	total: 825ms	remaining: 2h 17m 33s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7865719018
# bestIteration = 194
#
# Shrink model to first 195 iterations.
#     3 | 32m51s |    0.78420 |    3.8044 |       41.0690 |          0.4885 |             4.7982 |      0.9173 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/3
# ../expmodel/106_bx_cat5_5_01/3/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7235659	best: 0.7235659 (0)	total: 1.05s	remaining: 2h 55m 26s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7871402535
# bestIteration = 146
#
# Shrink model to first 147 iterations.
# ../expmodel/106_bx_cat5_5_01/3/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.7161896	best: 0.7161896 (0)	total: 1.1s	remaining: 3h 3m 6s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7844864924
# bestIteration = 151
#
# Shrink model to first 152 iterations.
# ../expmodel/106_bx_cat5_5_01/3/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7166461	best: 0.7166461 (0)	total: 1.9s	remaining: 5h 16m 38s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7838741981
# bestIteration = 93
#
# Shrink model to first 94 iterations.
# ../expmodel/106_bx_cat5_5_01/3/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.7176373	best: 0.7176373 (0)	total: 1.19s	remaining: 3h 18m 27s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7847355697
# bestIteration = 126
#
# Shrink model to first 127 iterations.
# ../expmodel/106_bx_cat5_5_01/3/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.7189011	best: 0.7189011 (0)	total: 1.14s	remaining: 3h 9m 24s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7875881559
# bestIteration = 104
#
# Shrink model to first 105 iterations.
#     4 | 39m12s |    0.78549 |    5.3462 |       41.4641 |          0.3560 |             5.1806 |      0.7833 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/4
# ../expmodel/106_bx_cat5_5_01/4/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7226529	best: 0.7226529 (0)	total: 1.41s	remaining: 3h 55m 10s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.790487289
# bestIteration = 309
#
# Shrink model to first 310 iterations.
# ../expmodel/106_bx_cat5_5_01/4/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.7170747	best: 0.7170747 (0)	total: 1.49s	remaining: 4h 8m 49s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7863415323
# bestIteration = 471
#
# Shrink model to first 472 iterations.
# ../expmodel/106_bx_cat5_5_01/4/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7166461	best: 0.7166461 (0)	total: 1.46s	remaining: 4h 2m 47s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7884046312
# bestIteration = 394
#
# Shrink model to first 395 iterations.
# ../expmodel/106_bx_cat5_5_01/4/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.7173556	best: 0.7173556 (0)	total: 1.45s	remaining: 4h 1m 43s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7894596785
# bestIteration = 361
#
# Shrink model to first 362 iterations.
# ../expmodel/106_bx_cat5_5_01/4/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.7193217	best: 0.7193217 (0)	total: 1.27s	remaining: 3h 32m 16s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7908440777
# bestIteration = 336
#
# Shrink model to first 337 iterations.
#     5 | 73m55s |    0.78906 |    5.0938 |       38.7235 |          0.1589 |             4.7709 |      0.9732 |
# Bayesian Optimization
# --------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |     depth |   l2_leaf_reg |   learning_rate |   scale_pos_weight |   subsample |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/5
# ../expmodel/106_bx_cat5_5_01/5/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7058863	best: 0.7058863 (0)	total: 536ms	remaining: 1h 29m 23s
# 1000:	test: 0.7909952	best: 0.7911148 (990)	total: 9m 20s	remaining: 1h 23m 57s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7912441057
# bestIteration = 1090
#
# Shrink model to first 1091 iterations.
# ../expmodel/106_bx_cat5_5_01/5/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.7041555	best: 0.7041555 (0)	total: 566ms	remaining: 1h 34m 22s
# 1000:	test: 0.7868463	best: 0.7870978 (949)	total: 9m 23s	remaining: 1h 24m 22s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7870977735
# bestIteration = 949
#
# Shrink model to first 950 iterations.
# ../expmodel/106_bx_cat5_5_01/5/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7006175	best: 0.7006175 (0)	total: 521ms	remaining: 1h 26m 52s
# 1000:	test: 0.7889213	best: 0.7891020 (892)	total: 9m 18s	remaining: 1h 23m 41s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7892734343
# bestIteration = 1064
#
# Shrink model to first 1065 iterations.
# ../expmodel/106_bx_cat5_5_01/5/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.6984768	best: 0.6984768 (0)	total: 596ms	remaining: 1h 39m 21s
# 1000:	test: 0.7899457	best: 0.7899457 (1000)	total: 9m 33s	remaining: 1h 25m 58s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7903452016
# bestIteration = 1277
#
# Shrink model to first 1278 iterations.
# ../expmodel/106_bx_cat5_5_01/5/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.6995790	best: 0.6995790 (0)	total: 547ms	remaining: 1h 31m 8s
# 1000:	test: 0.7926070	best: 0.7927226 (930)	total: 9m 24s	remaining: 1h 24m 37s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7929115575
# bestIteration = 1081
#
# Shrink model to first 1082 iterations.
#     6 | 65m07s |    0.79015 |    3.0680 |       38.1449 |          0.1452 |             5.4779 |      0.7084 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/6
# ../expmodel/106_bx_cat5_5_01/6/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7049869	best: 0.7049869 (0)	total: 737ms	remaining: 2h 2m 48s
# 1000:	test: 0.7917309	best: 0.7918096 (989)	total: 13m 3s	remaining: 1h 57m 27s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7923169324
# bestIteration = 1252
#
# Shrink model to first 1253 iterations.
# ../expmodel/106_bx_cat5_5_01/6/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.6979556	best: 0.6979556 (0)	total: 754ms	remaining: 2h 5m 36s
# 1000:	test: 0.7871069	best: 0.7871809 (984)	total: 13m 23s	remaining: 2h 20s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7879700774
# bestIteration = 1681
#
# Shrink model to first 1682 iterations.
# ../expmodel/106_bx_cat5_5_01/6/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7005832	best: 0.7005832 (0)	total: 738ms	remaining: 2h 2m 59s
# 1000:	test: 0.7886774	best: 0.7886832 (999)	total: 13m 36s	remaining: 2h 2m 23s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7890021797
# bestIteration = 1315
#
# Shrink model to first 1316 iterations.
# ../expmodel/106_bx_cat5_5_01/6/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.6992342	best: 0.6992342 (0)	total: 755ms	remaining: 2h 5m 50s
# 1000:	test: 0.7897322	best: 0.7898049 (988)	total: 13m 16s	remaining: 1h 59m 22s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7900303271
# bestIteration = 1155
#
# Shrink model to first 1156 iterations.
# ../expmodel/106_bx_cat5_5_01/6/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.7017444	best: 0.7017444 (0)	total: 804ms	remaining: 2h 14m 2s
# 1000:	test: 0.7923705	best: 0.7924121 (982)	total: 13m 40s	remaining: 2h 2m 56s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7929373537
# bestIteration = 1254
#
# Shrink model to first 1255 iterations.
#     7 | 106m57s |    0.79041 |    3.6958 |       39.2879 |          0.1025 |             5.4989 |      0.9958 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/7
# ../expmodel/106_bx_cat5_5_01/7/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7231195	best: 0.7231195 (0)	total: 970ms	remaining: 2h 41m 41s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7924518213
# bestIteration = 604
#
# Shrink model to first 605 iterations.
# ../expmodel/106_bx_cat5_5_01/7/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.7170983	best: 0.7170983 (0)	total: 1.04s	remaining: 2h 52m 56s
# 1000:	test: 0.7869120	best: 0.7875322 (859)	total: 19m 47s	remaining: 2h 57m 57s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7875321661
# bestIteration = 859
#
# Shrink model to first 860 iterations.
# ../expmodel/106_bx_cat5_5_01/7/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7174357	best: 0.7174357 (0)	total: 1.13s	remaining: 3h 9m 5s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7903760599
# bestIteration = 756
#
# Shrink model to first 757 iterations.
# ../expmodel/106_bx_cat5_5_01/7/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.7162280	best: 0.7162280 (0)	total: 1.53s	remaining: 4h 15m
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7893740187
# bestIteration = 480
#
# Shrink model to first 481 iterations.
# ../expmodel/106_bx_cat5_5_01/7/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.7201447	best: 0.7201447 (0)	total: 1.36s	remaining: 3h 47m 9s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7927710798
# bestIteration = 686
#
# Shrink model to first 687 iterations.
#     8 | 110m45s |    0.79044 |    5.9046 |       38.0959 |          0.1080 |             5.4550 |      0.8223 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/8
# ../expmodel/106_bx_cat5_5_01/8/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7045846	best: 0.7045846 (0)	total: 939ms	remaining: 2h 36m 28s
# 1000:	test: 0.7919750	best: 0.7920557 (973)	total: 17m 12s	remaining: 2h 34m 42s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.79219039
# bestIteration = 1063
#
# Shrink model to first 1064 iterations.
# ../expmodel/106_bx_cat5_5_01/8/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.6979556	best: 0.6979556 (0)	total: 788ms	remaining: 2h 11m 23s
# 1000:	test: 0.7878903	best: 0.7878998 (994)	total: 16m 34s	remaining: 2h 29m 1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7883566034
# bestIteration = 1333
#
# Shrink model to first 1334 iterations.
# ../expmodel/106_bx_cat5_5_01/8/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7026010	best: 0.7026010 (0)	total: 995ms	remaining: 2h 45m 50s
# 1000:	test: 0.7894661	best: 0.7894757 (974)	total: 16m 40s	remaining: 2h 29m 53s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7899830024
# bestIteration = 1309
#
# Shrink model to first 1310 iterations.
# ../expmodel/106_bx_cat5_5_01/8/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.6992342	best: 0.6992342 (0)	total: 989ms	remaining: 2h 44m 53s
# 1000:	test: 0.7896655	best: 0.7896669 (906)	total: 18m 16s	remaining: 2h 44m 14s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.790289099
# bestIteration = 1158
#
# Shrink model to first 1159 iterations.
# ../expmodel/106_bx_cat5_5_01/8/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.6948664	best: 0.6948664 (0)	total: 1.62s	remaining: 4h 29m 46s
# 1000:	test: 0.7925921	best: 0.7927180 (978)	total: 16m 55s	remaining: 2h 32m 6s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7927180064
# bestIteration = 978
#
# Shrink model to first 979 iterations.
#     9 | 122m21s |    0.79067 |    3.0602 |       38.1033 |          0.1109 |             5.2010 |      0.9770 |
# feats num: 696
# model folder: ../expmodel/106_bx_cat5_5_01/9
# ../expmodel/106_bx_cat5_5_01/9/CatBoost_0.pickle not exists, going to train.
# 0:	test: 0.7045031	best: 0.7045031 (0)	total: 1.26s	remaining: 3h 30m 7s
# 1000:	test: 0.7918278	best: 0.7918423 (993)	total: 16m 26s	remaining: 2h 27m 48s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7923972496
# bestIteration = 1581
#
# Shrink model to first 1582 iterations.
# ../expmodel/106_bx_cat5_5_01/9/CatBoost_1.pickle not exists, going to train.
# 0:	test: 0.6979556	best: 0.6979556 (0)	total: 1.36s	remaining: 3h 46m 14s
# 1000:	test: 0.7868569	best: 0.7868583 (998)	total: 17m 24s	remaining: 2h 36m 27s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7880187591
# bestIteration = 1477
#
# Shrink model to first 1478 iterations.
# ../expmodel/106_bx_cat5_5_01/9/CatBoost_2.pickle not exists, going to train.
# 0:	test: 0.7005832	best: 0.7005832 (0)	total: 925ms	remaining: 2h 34m 12s
# 1000:	test: 0.7894234	best: 0.7894864 (995)	total: 13m 58s	remaining: 2h 5m 34s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7900695112
# bestIteration = 1427
#
# Shrink model to first 1428 iterations.
# ../expmodel/106_bx_cat5_5_01/9/CatBoost_3.pickle not exists, going to train.
# 0:	test: 0.6980710	best: 0.6980710 (0)	total: 676ms	remaining: 1h 52m 42s
# 1000:	test: 0.7896393	best: 0.7896737 (991)	total: 12m 21s	remaining: 1h 51m 4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7905677309
# bestIteration = 1496
#
# Shrink model to first 1497 iterations.
# ../expmodel/106_bx_cat5_5_01/9/CatBoost_4.pickle not exists, going to train.
# 0:	test: 0.6995328	best: 0.6995328 (0)	total: 678ms	remaining: 1h 52m 57s
# 1000:	test: 0.7930950	best: 0.7930950 (1000)	total: 12m 21s	remaining: 1h 51m 5s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.79381407
# bestIteration = 1262
#
# Shrink model to first 1263 iterations.
#    10 | 123m59s |    0.79094 |    3.1054 |       38.1214 |          0.1051 |             5.4535 |      0.9376 |
# [Done] BayesianOptimization: at 2018-08-28 11:58:19.282358

# %%
bo.res['max']
# Out:
# {'max_val': 0.7909412030768752,
#  'max_params': {'learning_rate': 0.10506322757096559,
#   'depth': 3.1053539767594875,
#   'l2_leaf_reg': 38.12140743351985,
#   'subsample': 0.9375666413595538,
#   'scale_pos_weight': 5.4535391282021015}}

# %%
"""
Shrink model to first 709 iterations.
    1 | 83m43s |    0.78989 |    3.0757 |       38.2374 |          0.1991 |             5.1549 |      0.7042 | 
feats num: 696
"""
feats[106]
col = 'AAO_PHONE__BIRTH'
X_train[[col]] = X_train[[col]].fillna(X_train[col].mean())
# Out:
# /Users/ylchen/.virtualenvs/ml-playground/lib/python3.6/site-packages/pandas/core/frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
def process_generated_feats(df, feats):
    sg = {
        '+': [], '-': [], '*': [], '/': [], '^':[]
    }
    x_dup_combos = [
        ('AAAO_SOURCES_MEAN__EMPLOYED_BIRTH', 'AAO_EMPLOYED__BIRTH'),
    ]
    o_dup_combos = [
        ('AAAX_CREDIT_ANNUITY__EMPLOYED', 'DAYS_EMPLOYED'),
        ('AAO_EMPLOYED__BIRTH', 'DAYS_EMPLOYED'),
        ('AAO_ANNUITY__INC', 'AAO_CREDIT__INC'),
    ]
    for feat in feats:
        if feat.startswith('*:') or \
            feat.startswith('/:') or \
            feat.startswith('+:') or \
            feat.startswith('-:') or \
            feat.startswith('^:'):
            operator = feat[0]
            f1, f2 = feat[2:].split('-')
            if operator == '*' and (f1, f2) in x_dup_combos:
                continue
            if operator == '/' and (f1, f2) in o_dup_combos:
                continue
            sg[operator].append((f1, f2))
    operators = {
         '*': np.multiply,
         '/': np.divide,
         '+': np.add,
         '-': np.subtract,
         '^': np.power
    }
    generated_feats = []
    for k, v in sg.items():
        for (f1, f2) in v:
            name = '{}:{}-{}'.format(k, f1, f2)
            generated_feats.append(name)
            df[name] = operators[k](df[f1], df[f2])
    return df, generated_feats

# %%
# -- lightgbm_10xx --
"""
# KFold 5

** Local: 0.792067, Submit: 0.796
LightGBM: 0.793998
LightGBM: 0.790757
LightGBM: 0.790989
LightGBM: 0.790886
LightGBM: 0.793755
- model/lgbm_10xx_5_1

* Local: 0.792063
LightGBM: 0.794158
LightGBM: 0.790051
LightGBM: 0.791403
LightGBM: 0.791301
LightGBM: 0.793603
- model/lgbm_10xpb_5_3


* Local: 0.791866
LightGBM: 0.794408
LightGBM: 0.790046
LightGBM: 0.791016
LightGBM: 0.790964
LightGBM: 0.792973
model/lgbm_10xpb_5_2
"""

# -- lightgbm_102 --
"""
## 0.791673(local), 0.796(submit) **
- lgmb_102_5_3
- KFold 5
"""

# %%
for i, r in cols['importance'].iteritems():
    if r == 0:
        print("'{}',".format(i))
        # print("'{}':'{}',".format(i, r))
# Out:
# 'WALLSMATERIAL_MODE_Block',
# 'FLAG_OWN_CAR',
# 'CC_AMT_TOTAL_RECEIVABLE_MIN',
# 'ORGANIZATION_TYPE_Business Entity Type 1',
# 'FONDKAPREMONT_MODE_reg oper account',
# 'WALLSMATERIAL_MODE_Panel',
# 'BASEMENTAREA_MODE',
# 'WALLSMATERIAL_MODE_Wooden',
# 'CC_NAME_CONTRACT_STATUS_Active_MIN',
# 'FLAG_EMAIL',
# 'BASEMENTAREA_MEDI',
# 'REG_CITY_NOT_WORK_CITY',
# 'ORGANIZATION_TYPE_Trade: type 7',
# 'WEEKDAY_APPR_PROCESS_START_THURSDAY',
# 'ACTIVE_MONTHS_BALANCE_MAX_MAX',
# 'ORGANIZATION_TYPE_Government',
# 'FONDKAPREMONT_MODE_org spec account',
# 'CC_NAME_CONTRACT_STATUS_Active_MEAN',
# 'ELEVATORS_MODE',
# 'FLOORSMAX_MEDI',
# 'POS_COUNT',
# 'OCCUPATION_TYPE_Security staff',
# 'HOUSETYPE_MODE_block of flats',
# 'PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN',
# 'PREV_CODE_REJECT_REASON_CLIENT_MEAN',
# 'PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN',
# 'LIVINGAPARTMENTS_MODE',
# 'NAME_CONTRACT_TYPE_Cash loans',
# 'NAME_CONTRACT_TYPE_Revolving loans',
# 'CLOSED_MONTHS_BALANCE_MAX_MAX',
# 'NAME_FAMILY_STATUS_Civil marriage',
# 'NAME_HOUSING_TYPE_With parents',
# 'NAME_TYPE_SUITE_Family',
# 'NAME_TYPE_SUITE_Unaccompanied',
# 'CNT_CHILDREN',
# 'CC_MONTHS_BALANCE_MAX',
# 'FLOORSMIN_MEDI',
# 'OCCUPATION_TYPE_Cleaning staff',
# 'CC_NAME_CONTRACT_STATUS_Signed_MEAN',
# 'BURO_MONTHS_BALANCE_MAX_MAX',
# 'OCCUPATION_TYPE_Private service staff',
# 'CC_AMT_TOTAL_RECEIVABLE_MEAN',
# 'CC_AMT_DRAWINGS_POS_CURRENT_MEAN',
# 'PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN',
